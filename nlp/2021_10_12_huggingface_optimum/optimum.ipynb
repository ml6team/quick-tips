# %% [markdown]
# ### Quantization with Huggingface Optimum (and ONNX Runtime)

# %% [markdown]
# Scaling and productionizing Transformers with millions of parameters are difficult tasks 😔.
#
# Addressing this, Huggingface just released a new tool called **Optimum** 💥(<html> https://huggingface.co/blog/hardware-partners-program </html>) which aims to speed up the inference time of Transformers. It enables ML practitioners to leverage the available hardware features to quantize the models.
#
#
# Quantization is the process of approximating models' parameters (and possibly activations) in floating point number by low bit width number. By doing this, the deep learning model size becomes smaller and takes less resources to run 👶.
#
#
# This notebook demonstrates some experiments on quantizing HF **pre-trained** models for *sentiment analysis* task, and also *summarization*. It also compares the performance of Optimum x Lpot quantization, ONNX/ONNX Runtime quantization, and the baseline model. The results are summarized in tables after Section 2 and Section 3.
#
# It's recommended to run this notebook using Google Cloud AI Platform using a N2-standard-4 CPU, since this supports modern optimization frameworks. Results when running on Colab will probably be less impressive in terms of speedup.

# %% [markdown]
# ## 1. Setting

# %%
# !pip install -q transformers datasets
# !pip install optimum[intel]
# Out:
#      |████████████████████████████████| 3.5 MB 6.0 MB/s
#      |████████████████████████████████| 311 kB 53.4 MB/s
#      |████████████████████████████████| 596 kB 3.1 MB/s
#      |████████████████████████████████| 895 kB 12.7 MB/s
#      |████████████████████████████████| 6.8 MB 4.7 MB/s
#      |████████████████████████████████| 67 kB 3.2 MB/s
#      |████████████████████████████████| 243 kB 42.1 MB/s
#      |████████████████████████████████| 133 kB 41.9 MB/s
#      |████████████████████████████████| 1.1 MB 46.4 MB/s
#      |████████████████████████████████| 94 kB 628 kB/s
#      |████████████████████████████████| 144 kB 38.0 MB/s
#      |████████████████████████████████| 271 kB 52.1 MB/s
# Collecting optimum[intel]
#   Downloading optimum-0.1.3-py3-none-any.whl (41 kB)
#      |████████████████████████████████| 41 kB 413 kB/s
# Collecting coloredlogs
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#      |████████████████████████████████| 46 kB 2.7 MB/s
# Requirement already satisfied: transformers>=4.12.0 in /usr/local/lib/python3.7/dist-packages (from optimum[intel]) (4.16.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.7/dist-packages (from optimum[intel]) (1.7.1)
# Requirement already satisfied: torch>=1.9 in /usr/local/lib/python3.7/dist-packages (from optimum[intel]) (1.10.0+cu111)
# Requirement already satisfied: datasets>=1.2.1 in /usr/local/lib/python3.7/dist-packages (from optimum[intel]) (1.18.3)
# Collecting neural-compressor>=1.7
#   Downloading neural_compressor-1.9.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (73.6 MB)
#      |████████████████████████████████| 73.6 MB 91 kB/s
# Requirement already satisfied: pycocotools in /usr/local/lib/python3.7/dist-packages (from optimum[intel]) (2.0.4)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from datasets>=1.2.1->optimum[intel]) (4.10.1)
# Requirement already satisfied: fsspec[http]>=2021.05.0 in /usr/local/lib/python3.7/dist-packages (from datasets>=1.2.1->optimum[intel]) (2022.1.0)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.7/dist-packages (from datasets>=1.2.1->optimum[intel]) (2.23.0)
# Requirement already satisfied: pyarrow!=4.0.0,>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from datasets>=1.2.1->optimum[intel]) (6.0.1)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.7/dist-packages (from datasets>=1.2.1->optimum[intel]) (3.8.1)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.1.0 in /usr/local/lib/python3.7/dist-packages (from datasets>=1.2.1->optimum[intel]) (0.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from datasets>=1.2.1->optimum[intel]) (21.3)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.7/dist-packages (from datasets>=1.2.1->optimum[intel]) (4.62.3)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.7/dist-packages (from datasets>=1.2.1->optimum[intel]) (0.70.12.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from datasets>=1.2.1->optimum[intel]) (1.3.5)
# Requirement already satisfied: dill in /usr/local/lib/python3.7/dist-packages (from datasets>=1.2.1->optimum[intel]) (0.3.4)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.7/dist-packages (from datasets>=1.2.1->optimum[intel]) (2.0.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from datasets>=1.2.1->optimum[intel]) (1.19.5)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets>=1.2.1->optimum[intel]) (3.10.0.2)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets>=1.2.1->optimum[intel]) (6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets>=1.2.1->optimum[intel]) (3.4.2)
# Requirement already satisfied: Flask in /usr/local/lib/python3.7/dist-packages (from neural-compressor>=1.7->optimum[intel]) (1.1.4)
# Collecting gevent
#   Downloading gevent-21.12.0-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (5.8 MB)
#      |████████████████████████████████| 5.8 MB 42.7 MB/s
# Requirement already satisfied: prettytable in /usr/local/lib/python3.7/dist-packages (from neural-compressor>=1.7->optimum[intel]) (3.0.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.7/dist-packages (from neural-compressor>=1.7->optimum[intel]) (5.4.8)
# Collecting py-cpuinfo
#   Downloading py-cpuinfo-8.0.0.tar.gz (99 kB)
#      |████████████████████████████████| 99 kB 5.4 MB/s
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.7/dist-packages (from neural-compressor>=1.7->optimum[intel]) (4.1.2.30)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from neural-compressor>=1.7->optimum[intel]) (1.0.2)
# Collecting Flask-SocketIO
#   Downloading Flask_SocketIO-5.1.1-py3-none-any.whl (17 kB)
# Requirement already satisfied: hyperopt in /usr/local/lib/python3.7/dist-packages (from neural-compressor>=1.7->optimum[intel]) (0.1.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.7/dist-packages (from neural-compressor>=1.7->optimum[intel]) (7.1.2)
# Collecting Flask-Cors
#   Downloading Flask_Cors-3.0.10-py2.py3-none-any.whl (14 kB)
# Collecting schema
#   Downloading schema-0.7.5-py2.py3-none-any.whl (17 kB)
# Collecting gevent-websocket
#   Downloading gevent_websocket-0.10.1-py3-none-any.whl (22 kB)
# Collecting sigopt
#   Downloading sigopt-8.2.0-py2.py3-none-any.whl (172 kB)
#      |████████████████████████████████| 172 kB 41.7 MB/s
# Collecting cryptography
#   Downloading cryptography-36.0.1-cp36-abi3-manylinux_2_24_x86_64.whl (3.6 MB)
#      |████████████████████████████████| 3.6 MB 13.7 MB/s
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->datasets>=1.2.1->optimum[intel]) (3.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets>=1.2.1->optimum[intel]) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets>=1.2.1->optimum[intel]) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets>=1.2.1->optimum[intel]) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets>=1.2.1->optimum[intel]) (2.10)
# Requirement already satisfied: tokenizers!=0.11.3,>=0.10.1 in /usr/local/lib/python3.7/dist-packages (from transformers>=4.12.0->optimum[intel]) (0.11.4)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers>=4.12.0->optimum[intel]) (2019.12.20)
# Requirement already satisfied: sacremoses in /usr/local/lib/python3.7/dist-packages (from transformers>=4.12.0->optimum[intel]) (0.0.47)
# Requirement already satisfied: asynctest==0.13.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets>=1.2.1->optimum[intel]) (0.13.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets>=1.2.1->optimum[intel]) (1.7.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets>=1.2.1->optimum[intel]) (21.4.0)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets>=1.2.1->optimum[intel]) (2.0.11)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets>=1.2.1->optimum[intel]) (4.0.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets>=1.2.1->optimum[intel]) (1.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets>=1.2.1->optimum[intel]) (6.0.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets>=1.2.1->optimum[intel]) (1.3.0)
# Collecting humanfriendly>=9.1
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#      |████████████████████████████████| 86 kB 4.9 MB/s
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.7/dist-packages (from cryptography->neural-compressor>=1.7->optimum[intel]) (1.15.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.12->cryptography->neural-compressor>=1.7->optimum[intel]) (2.21)
# Requirement already satisfied: Jinja2<3.0,>=2.10.1 in /usr/local/lib/python3.7/dist-packages (from Flask->neural-compressor>=1.7->optimum[intel]) (2.11.3)
# Requirement already satisfied: Werkzeug<2.0,>=0.15 in /usr/local/lib/python3.7/dist-packages (from Flask->neural-compressor>=1.7->optimum[intel]) (1.0.1)
# Requirement already satisfied: itsdangerous<2.0,>=0.24 in /usr/local/lib/python3.7/dist-packages (from Flask->neural-compressor>=1.7->optimum[intel]) (1.1.0)
# Requirement already satisfied: click<8.0,>=5.1 in /usr/local/lib/python3.7/dist-packages (from Flask->neural-compressor>=1.7->optimum[intel]) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from Jinja2<3.0,>=2.10.1->Flask->neural-compressor>=1.7->optimum[intel]) (2.0.1)
# Requirement already satisfied: Six in /usr/local/lib/python3.7/dist-packages (from Flask-Cors->neural-compressor>=1.7->optimum[intel]) (1.15.0)
# Collecting python-socketio>=5.0.2
#   Downloading python_socketio-5.5.1-py3-none-any.whl (56 kB)
#      |████████████████████████████████| 56 kB 3.1 MB/s
# Collecting bidict>=0.21.0
#   Downloading bidict-0.21.4-py3-none-any.whl (36 kB)
# Collecting python-engineio>=4.3.0
#   Downloading python_engineio-4.3.1-py3-none-any.whl (52 kB)
#      |████████████████████████████████| 52 kB 1.1 MB/s
# Requirement already satisfied: greenlet<2.0,>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from gevent->neural-compressor>=1.7->optimum[intel]) (1.1.2)
# Collecting zope.interface
#   Downloading zope.interface-5.4.0-cp37-cp37m-manylinux2010_x86_64.whl (251 kB)
#      |████████████████████████████████| 251 kB 56.1 MB/s
# Collecting zope.event
#   Downloading zope.event-4.5.0-py2.py3-none-any.whl (6.8 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from gevent->neural-compressor>=1.7->optimum[intel]) (57.4.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.7/dist-packages (from hyperopt->neural-compressor>=1.7->optimum[intel]) (2.6.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from hyperopt->neural-compressor>=1.7->optimum[intel]) (1.4.1)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from hyperopt->neural-compressor>=1.7->optimum[intel]) (0.16.0)
# Requirement already satisfied: pymongo in /usr/local/lib/python3.7/dist-packages (from hyperopt->neural-compressor>=1.7->optimum[intel]) (4.0.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->datasets>=1.2.1->optimum[intel]) (3.7.0)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets>=1.2.1->optimum[intel]) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets>=1.2.1->optimum[intel]) (2.8.2)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.7/dist-packages (from prettytable->neural-compressor>=1.7->optimum[intel]) (0.2.5)
# Requirement already satisfied: matplotlib>=2.1.0 in /usr/local/lib/python3.7/dist-packages (from pycocotools->optimum[intel]) (3.2.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=2.1.0->pycocotools->optimum[intel]) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=2.1.0->pycocotools->optimum[intel]) (1.3.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers>=4.12.0->optimum[intel]) (1.1.0)
# Requirement already satisfied: contextlib2>=0.5.5 in /usr/local/lib/python3.7/dist-packages (from schema->neural-compressor>=1.7->optimum[intel]) (0.5.5)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->neural-compressor>=1.7->optimum[intel]) (3.1.0)
# Collecting pyyaml
#   Downloading PyYAML-5.4.1-cp37-cp37m-manylinux1_x86_64.whl (636 kB)
#      |████████████████████████████████| 636 kB 39.6 MB/s
# Collecting Pint<0.17.0,>=0.16.0
#   Downloading Pint-0.16.1-py2.py3-none-any.whl (205 kB)
#      |████████████████████████████████| 205 kB 55.6 MB/s
# Requirement already satisfied: ipython>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from sigopt->neural-compressor>=1.7->optimum[intel]) (5.5.0)
# Collecting pyOpenSSL>=20.0.0
#   Downloading pyOpenSSL-22.0.0-py2.py3-none-any.whl (55 kB)
#      |████████████████████████████████| 55 kB 3.4 MB/s
# Collecting boto3<2.0.0,==1.16.34
#   Downloading boto3-1.16.34-py2.py3-none-any.whl (129 kB)
#      |████████████████████████████████| 129 kB 39.8 MB/s
# Collecting docker<5.0.0,>=4.4.0
#   Downloading docker-4.4.4-py2.py3-none-any.whl (147 kB)
#      |████████████████████████████████| 147 kB 50.1 MB/s
# Collecting GitPython>=2.0.0
#   Downloading GitPython-3.1.26-py3-none-any.whl (180 kB)
#      |████████████████████████████████| 180 kB 42.6 MB/s
# Collecting sigopt
#   Downloading sigopt-8.1.3-py2.py3-none-any.whl (172 kB)
#      |████████████████████████████████| 172 kB 44.8 MB/s
#   Downloading sigopt-8.1.2-py2.py3-none-any.whl (159 kB)
#      |████████████████████████████████| 159 kB 45.7 MB/s
#   Downloading sigopt-8.1.1-py2.py3-none-any.whl (159 kB)
#      |████████████████████████████████| 159 kB 50.8 MB/s
#   Downloading sigopt-8.1.0-py2.py3-none-any.whl (159 kB)
#      |████████████████████████████████| 159 kB 54.2 MB/s
#   Downloading sigopt-8.0.1-py2.py3-none-any.whl (176 kB)
#      |████████████████████████████████| 176 kB 61.2 MB/s
#   Downloading sigopt-8.0.0-py2.py3-none-any.whl (156 kB)
#      |████████████████████████████████| 156 kB 38.0 MB/s
#   Downloading sigopt-7.5.0-py2.py3-none-any.whl (38 kB)
# Collecting pypng>=0.0.20
#   Downloading pypng-0.0.21-py3-none-any.whl (48 kB)
#      |████████████████████████████████| 48 kB 4.6 MB/s
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.9-py3-none-any.whl (63 kB)
#      |████████████████████████████████| 63 kB 1.6 MB/s
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: simplegeneric>0.8 in /usr/local/lib/python3.7/dist-packages (from ipython>=5.0.0->sigopt->neural-compressor>=1.7->optimum[intel]) (0.8.1)
# Requirement already satisfied: pygments in /usr/local/lib/python3.7/dist-packages (from ipython>=5.0.0->sigopt->neural-compressor>=1.7->optimum[intel]) (2.6.1)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.7/dist-packages (from ipython>=5.0.0->sigopt->neural-compressor>=1.7->optimum[intel]) (4.8.0)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.7/dist-packages (from ipython>=5.0.0->sigopt->neural-compressor>=1.7->optimum[intel]) (5.1.1)
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/dist-packages (from ipython>=5.0.0->sigopt->neural-compressor>=1.7->optimum[intel]) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.7/dist-packages (from ipython>=5.0.0->sigopt->neural-compressor>=1.7->optimum[intel]) (0.7.5)
# Requirement already satisfied: prompt-toolkit<2.0.0,>=1.0.4 in /usr/local/lib/python3.7/dist-packages (from ipython>=5.0.0->sigopt->neural-compressor>=1.7->optimum[intel]) (1.0.18)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.7/dist-packages (from pexpect->ipython>=5.0.0->sigopt->neural-compressor>=1.7->optimum[intel]) (0.7.0)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.7/dist-packages (from sympy->optimum[intel]) (1.2.1)
# Building wheels for collected packages: py-cpuinfo
#   Building wheel for py-cpuinfo (setup.py) ... done
#   Created wheel for py-cpuinfo: filename=py_cpuinfo-8.0.0-py3-none-any.whl size=22257 sha256=39683795f50c6882287879ded544b6480a3a3ebf325e1e4a83d1cb0c92e6c2f9
#   Stored in directory: /root/.cache/pip/wheels/d2/f1/1f/041add21dc9c4220157f1bd2bd6afe1f1a49524c3396b94401
# Successfully built py-cpuinfo
# Installing collected packages: smmap, zope.interface, zope.event, python-engineio, gitdb, bidict, python-socketio, pypng, humanfriendly, GitPython, gevent, sigopt, schema, py-cpuinfo, gevent-websocket, Flask-SocketIO, Flask-Cors, cryptography, coloredlogs, optimum, neural-compressor
# Successfully installed Flask-Cors-3.0.10 Flask-SocketIO-5.1.1 GitPython-3.1.26 bidict-0.21.4 coloredlogs-15.0.1 cryptography-36.0.1 gevent-21.12.0 gevent-websocket-0.10.1 gitdb-4.0.9 humanfriendly-10.0 neural-compressor-1.9.1 optimum-0.1.3 py-cpuinfo-8.0.0 pypng-0.0.21 python-engineio-4.3.1 python-socketio-5.5.1 schema-0.7.5 sigopt-7.5.0 smmap-5.0.0 zope.event-4.5.0 zope.interface-5.4.0

# %%
# !pip install -q onnxruntime onnxruntime-gpu onnxruntime-tools onnx psutil
# Out:
#      |████████████████████████████████| 4.9 MB 22.7 MB/s
#      |████████████████████████████████| 104.8 MB 93 kB/s
#      |████████████████████████████████| 212 kB 60.1 MB/s
#      |████████████████████████████████| 12.7 MB 49.6 MB/s
#      |████████████████████████████████| 55 kB 2.9 MB/s

# %%
# import unittest
import time
import os
# os.environ["CUDA_VISIBLE_DEVICES"] = ""
import numpy as np

from transformers import (
    AutoConfig,
    AutoModelForSequenceClassification,
    AutoTokenizer,
    EvalPrediction,
    Trainer,
    default_data_collator,
    TrainingArguments,
    pipeline
)
from datasets import load_dataset, load_metric, list_metrics
import optimum.intel.neural_compressor
from optimum.intel.neural_compressor.quantization import IncQuantizer, IncQuantizerForSequenceClassification

# %%
task_to_keys = {
    "cola": ("sentence", None),
    "mnli": ("premise", "hypothesis"),
    "mrpc": ("sentence1", "sentence2"),
    "qnli": ("question", "sentence"),
    "qqp": ("question1", "question2"),
    "rte": ("sentence1", "sentence2"),
    "sst2": ("sentence", None),
    "stsb": ("sentence1", "sentence2"),
    "wnli": ("sentence1", "sentence2"),
    "summarization": ("article", None)
}

# %% [markdown]
# ## 2. Quantization - Sentiment analysis 🎭

# %% [markdown]
# We first perform the quantization based on a sentiment analysis task. The cell below is the configurations of the pretrained model, its assigned task (sentiment analysis), and the name of the validation dataset which will later on be useful for the quantization.

# %%
model_name = "textattack/bert-base-uncased-SST-2"
# config_path = "content/"
task = "sst2"
padding = "max_length"
max_seq_length = 128
max_eval_samples = 200
metric_name = "eval_accuracy"
dataset = load_dataset("glue", task, split="validation")
metric = load_metric("glue", task)
data_collator = default_data_collator
sentence1_key, sentence2_key = task_to_keys[task]
# Out:
# Downloading:   0%|          | 0.00/7.78k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/4.47k [00:00<?, ?B/s]
# Downloading and preparing dataset glue/sst2 (download: 7.09 MiB, generated: 4.81 MiB, post-processed: Unknown size, total: 11.90 MiB) to /root/.cache/huggingface/datasets/glue/sst2/1.0.0/dacbe3125aa31d7f70367a07a8a9e72a5a0bfeb5fc42e75c9db75b96da6053ad...
# Downloading:   0%|          | 0.00/7.44M [00:00<?, ?B/s]
# 0 examples [00:00, ? examples/s]
# 0 examples [00:00, ? examples/s]
# 0 examples [00:00, ? examples/s]
# Dataset glue downloaded and prepared to /root/.cache/huggingface/datasets/glue/sst2/1.0.0/dacbe3125aa31d7f70367a07a8a9e72a5a0bfeb5fc42e75c9db75b96da6053ad. Subsequent calls will reuse this data.
# Downloading:   0%|          | 0.00/1.84k [00:00<?, ?B/s]

# %% [markdown]
# ### Neural compressor quantization

# %% [markdown]
# Configure a neural compressor-based Quantizer for sequence classification which is suitable for the task at hand (SST2). As a side note, neural compressor, (previously called Lpot - or Intel® Low Precision Optimization Tool), is a tool that supports automatic accuracy-driven tuning strategies to help user quickly find out the best quantized model. Interested reader can find more in <html> https://github.com/intel/neural-compressor </html>.

# %% [markdown]
# Downloading the config yaml file:

# %%
# !wget https://raw.githubusercontent.com/ml6team/quick-tips/main/nlp/2021_10_12_huggingface_optimum/quantization.yml .
# Out:
# --2022-02-14 10:02:20--  https://raw.githubusercontent.com/ml6team/quick-tips/main/nlp/2021_10_12_huggingface_optimum/quantization.yml
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1595 (1.6K) [text/plain]
# Saving to: ‘quantization.yml’
#
# quantization.yml    100%[===================>]   1.56K  --.-KB/s    in 0s
#
# 2022-02-14 10:02:20 (24.8 MB/s) - ‘quantization.yml’ saved [1595/1595]
#
# --2022-02-14 10:02:20--  http://./
# Resolving . (.)... failed: No address associated with hostname.
# wget: unable to resolve host address ‘.’
# FINISHED --2022-02-14 10:02:20--
# Total wall clock time: 0.1s
# Downloaded: 1 files, 1.6K in 0s (24.8 MB/s)

# %% [markdown]
# Defining the quantizer:

# %%
quantizer = IncQuantizerForSequenceClassification.from_config(
    model_name_or_path = "textattack/bert-base-uncased-SST-2",
    inc_config="quantization.yml"
)
# Out:
# Downloading:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/477 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/226k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/418M [00:00<?, ?B/s]

# %% [markdown]
# We can directly use the pretrained model for predictions of sentiment analysis task. Before focusing on prediction, let us perform quantization to tune the model. The cells below are the necessary components that enable us to perform quantization on this pretrained model.

# %%
tokenizer = quantizer.tokenizer
model = quantizer.model

# %% [markdown]
# For the pre-processing of the evaluation data:

# %%
def preprocess_function(examples):
  args = (
    (examples[sentence1_key],) if sentence2_key is None else (
    examples[sentence1_key], examples[sentence2_key])
  )
  result = tokenizer(*args, padding=padding, max_length=max_seq_length, truncation=True)
  return result

eval_dataset = dataset.map(preprocess_function, batched=True)
eval_dataset = eval_dataset.select(range(max_eval_samples))
# Out:
#   0%|          | 0/1 [00:00<?, ?ba/s]

# %% [markdown]
# The evaluation data is now stored in `eval_dataset`. The cells below help us define the metrics to compute. Note that for the task SST2, the dataset for `glue` is the movie reviews and human annotations of their sentiment (Stanford Sentiment Treebank), with accuracy is the evaluation criteria.

# %%
def compute_metrics(p: EvalPrediction):
  preds = p.predictions[0] if isinstance(p.predictions, tuple) else p.predictions
  preds = np.argmax(preds, axis=1)
  result = metric.compute(predictions=preds, references=p.label_ids)
  if len(result) > 1:
    result["combined_score"] = np.mean(list(result.values())).item()
  print(result)
  return result

# %% [markdown]
# We are now ready to initiate a `Trainer` object that can be used to evaluate model accuracy during the tuning phase of quantization.

# %%
trainer = Trainer(
            model=model,
            eval_dataset=eval_dataset,
            compute_metrics=compute_metrics,
            tokenizer=tokenizer,
            data_collator=data_collator,
        )

# %%
def take_eval_steps(model, trainer, metric_name):
  trainer.model = model
  metrics = trainer.evaluate()
  return metrics.get(metric_name)

def eval_func(model):
  return take_eval_steps(model, trainer, metric_name)

# %%
quantizer.eval_func = eval_func
q_model = quantizer.fit_dynamic()
# Out:
# 2022-02-14 10:45:08 [INFO] Pass query framework capability elapsed time: 3.32 ms
# 2022-02-14 10:45:08 [INFO] Get FP32 model baseline.
# The following columns in the evaluation set  don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: idx, sentence.
# ***** Running Evaluation *****
#   Num examples = 200
#   Batch size = 8
#     <div>
#
#       <progress value='50' max='25' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [25/25 02:28]
#     </div>
# 2022-02-14 10:46:33 [INFO] Save tuning history to /content/nc_workspace/2022-02-14_10-00-09/./history.snapshot.
# 2022-02-14 10:46:33 [INFO] FP32 baseline is: [Accuracy: 0.9150, Duration (seconds): 85.7602]
# {'accuracy': 0.915}
# 2022-02-14 10:46:35 [INFO] |*****Mixed Precision Statistics*****|
# 2022-02-14 10:46:35 [INFO] +--------------+-----------+---------+
# 2022-02-14 10:46:35 [INFO] |   Op Type    |   Total   |   INT8  |
# 2022-02-14 10:46:35 [INFO] +--------------+-----------+---------+
# 2022-02-14 10:46:35 [INFO] |    Linear    |     74    |    74   |
# 2022-02-14 10:46:35 [INFO] +--------------+-----------+---------+
# 2022-02-14 10:46:35 [INFO] Pass quantize model elapsed time: 2108.28 ms
# The following columns in the evaluation set  don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: idx, sentence.
# ***** Running Evaluation *****
#   Num examples = 200
#   Batch size = 8
# 2022-02-14 10:47:40 [INFO] Tune 1 result is: [Accuracy (int8|fp32): 0.9100|0.9150, Duration (seconds) (int8|fp32): 64.7209|85.7602], Best tune result is: [Accuracy: 0.9100, Duration (seconds): 64.7209]
# 2022-02-14 10:47:40 [INFO] Save tuning history to /content/nc_workspace/2022-02-14_10-00-09/./history.snapshot.
# 2022-02-14 10:47:40 [INFO] Specified timeout or max trials is reached! Found a quantized model which meet accuracy goal. Exit.
# 2022-02-14 10:47:40 [INFO] Save deploy yaml to /content/nc_workspace/2022-02-14_10-00-09/deploy.yaml
# {'accuracy': 0.91}

# %% [markdown]
# A quantized model is found! Let's investigate how much time does it take to perform inference on the validation set.

# %%
start_time = time.time()
metric_quantized = take_eval_steps(q_model.model, trainer, metric_name)
elapsed_time = time.time() - start_time
print(f"Quantized model obtained with {metric_name} of {metric_quantized}, time elapsed: {elapsed_time}")
# Out:
# The following columns in the evaluation set  don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: idx, sentence.
# ***** Running Evaluation *****
#   Num examples = 200
#   Batch size = 8
#     <div>
#
#       <progress value='75' max='25' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [25/25 03:53]
#     </div>
# {'accuracy': 0.91}
# Quantized model obtained with eval_accuracy of 0.91, time elapsed: 70.50518870353699

# %% [markdown]
# ### ONNX quantization

# %% [markdown]
# Another approach to quantization is using ONNX/ONNX Runtime (<html> https://huggingface.co/transformers/serialization.html </html>). We first export the pretrained model to ONNX format, and then optimize and quantize it. The quantized model will perform inference on `eval_dataset`.

# %%
# !rm -rf onnx/ 
from pathlib import Path
from transformers import AutoTokenizer
from transformers.convert_graph_to_onnx import convert

# Exporting the model to ONNX
convert(pipeline_name="sentiment-analysis",
        framework="pt",
        model="textattack/bert-base-uncased-SST-2",
        tokenizer="textattack/bert-base-uncased-SST-2",
        output=Path("onnx/bert-base-uncased-SST-2.onnx"),
        opset=11)
# Out:
# loading configuration file https://huggingface.co/textattack/bert-base-uncased-SST-2/resolve/main/config.json from cache at /root/.cache/huggingface/transformers/293ab95645c102b941dee443ccf73fb9b5b5a9706b9893f09b5f1941b1bd0c8b.32da30c4245b376f0c4fd55aaf1c536c5ef13f10c248390e0311fcb4ca48f475
# Model config BertConfig {
#   "_name_or_path": "textattack/bert-base-uncased-SST-2",
#   "architectures": [
#     "BertForSequenceClassification"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "finetuning_task": "sst-2",
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.16.2",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 30522
# }
#
# loading configuration file https://huggingface.co/textattack/bert-base-uncased-SST-2/resolve/main/config.json from cache at /root/.cache/huggingface/transformers/293ab95645c102b941dee443ccf73fb9b5b5a9706b9893f09b5f1941b1bd0c8b.32da30c4245b376f0c4fd55aaf1c536c5ef13f10c248390e0311fcb4ca48f475
# Model config BertConfig {
#   "_name_or_path": "textattack/bert-base-uncased-SST-2",
#   "architectures": [
#     "BertForSequenceClassification"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "finetuning_task": "sst-2",
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.16.2",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 30522
# }
#
# loading weights file https://huggingface.co/textattack/bert-base-uncased-SST-2/resolve/main/pytorch_model.bin from cache at /root/.cache/huggingface/transformers/a7511de9d84e49d590d1debe392368a67a14cccc4bde4f72d766705702d2edd9.495764b52432aefa3c4d3988b595993be3f3d1e407c2cb9f3d5eb4ff4e886d1d
# ONNX opset version set to: 11
# Loading pipeline (model: textattack/bert-base-uncased-SST-2, tokenizer: textattack/bert-base-uncased-SST-2)
# All model checkpoint weights were used when initializing BertForSequenceClassification.
#
# All the weights of BertForSequenceClassification were initialized from the model checkpoint at textattack/bert-base-uncased-SST-2.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use BertForSequenceClassification for predictions without further training.
# loading configuration file https://huggingface.co/textattack/bert-base-uncased-SST-2/resolve/main/config.json from cache at /root/.cache/huggingface/transformers/293ab95645c102b941dee443ccf73fb9b5b5a9706b9893f09b5f1941b1bd0c8b.32da30c4245b376f0c4fd55aaf1c536c5ef13f10c248390e0311fcb4ca48f475
# Model config BertConfig {
#   "_name_or_path": "textattack/bert-base-uncased-SST-2",
#   "architectures": [
#     "BertForSequenceClassification"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "finetuning_task": "sst-2",
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.16.2",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 30522
# }
#
# loading file https://huggingface.co/textattack/bert-base-uncased-SST-2/resolve/main/vocab.txt from cache at /root/.cache/huggingface/transformers/9c8dda35c85d8852699ae2daa805d96a9e139eb93ab411edd3e7de9ff27c131f.d789d64ebfe299b0e416afc4a169632f903f693095b4629a7ea271d5a0cf2c99
# loading file https://huggingface.co/textattack/bert-base-uncased-SST-2/resolve/main/tokenizer.json from cache at None
# loading file https://huggingface.co/textattack/bert-base-uncased-SST-2/resolve/main/added_tokens.json from cache at None
# loading file https://huggingface.co/textattack/bert-base-uncased-SST-2/resolve/main/special_tokens_map.json from cache at /root/.cache/huggingface/transformers/c7c9b9c5d8bab3ba2ddaa08b138aa385f9790f30e8dce3bfe47e3f10bd97f4ad.dd8bd9bfd3664b530ea4e645105f557769387b3da9f79bdb55ed556bdd80611d
# loading file https://huggingface.co/textattack/bert-base-uncased-SST-2/resolve/main/tokenizer_config.json from cache at /root/.cache/huggingface/transformers/b0a5f8537502519294ee167d172bf5daff91c9277ffc722e9f46d6c8c05d2f55.76ea01b4b85ac16e2cec55c398cba7a943d89ab21dfdd973f6630a152e4b9aed
# loading configuration file https://huggingface.co/textattack/bert-base-uncased-SST-2/resolve/main/config.json from cache at /root/.cache/huggingface/transformers/293ab95645c102b941dee443ccf73fb9b5b5a9706b9893f09b5f1941b1bd0c8b.32da30c4245b376f0c4fd55aaf1c536c5ef13f10c248390e0311fcb4ca48f475
# Model config BertConfig {
#   "_name_or_path": "textattack/bert-base-uncased-SST-2",
#   "architectures": [
#     "BertForSequenceClassification"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "finetuning_task": "sst-2",
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.16.2",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 30522
# }
#
# loading configuration file https://huggingface.co/textattack/bert-base-uncased-SST-2/resolve/main/config.json from cache at /root/.cache/huggingface/transformers/293ab95645c102b941dee443ccf73fb9b5b5a9706b9893f09b5f1941b1bd0c8b.32da30c4245b376f0c4fd55aaf1c536c5ef13f10c248390e0311fcb4ca48f475
# Model config BertConfig {
#   "_name_or_path": "textattack/bert-base-uncased-SST-2",
#   "architectures": [
#     "BertForSequenceClassification"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "finetuning_task": "sst-2",
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.16.2",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 30522
# }
# Creating folder onnx
# Using framework PyTorch: 1.10.0+cu111
# Found input input_ids with shape: {0: 'batch', 1: 'sequence'}
# Found input token_type_ids with shape: {0: 'batch', 1: 'sequence'}
# Found input attention_mask with shape: {0: 'batch', 1: 'sequence'}
# Found output output_0 with shape: {0: 'batch'}
# Ensuring inputs are in correct order
# position_ids is not present in the generated input list.
# Generated inputs order: ['input_ids', 'attention_mask', 'token_type_ids']
# /usr/local/lib/python3.7/dist-packages/torch/onnx/utils.py:90: UserWarning: 'enable_onnx_checker' is deprecated and ignored. It will be removed in the next PyTorch release. To proceed despite ONNX checker failures, catch torch.onnx.ONNXCheckerError.
#   warnings.warn("'enable_onnx_checker' is deprecated and ignored. It will be removed in "
# /usr/local/lib/python3.7/dist-packages/torch/onnx/utils.py:103: UserWarning: `use_external_data_format' is deprecated and ignored. Will be removed in next PyTorch release. The code will work as it is False if models are not larger than 2GB, Otherwise set to False because of size limits imposed by Protocol Buffers.
#   warnings.warn("`use_external_data_format' is deprecated and ignored. Will be removed in next "

# %%
from onnxruntime import GraphOptimizationLevel, InferenceSession, SessionOptions, get_all_providers
from contextlib import contextmanager
from dataclasses import dataclass
from time import time
from tqdm import trange

def create_model_for_provider(model_path: str, provider: str) -> InferenceSession: 
  
  assert provider in get_all_providers(), f"provider {provider} not found, {get_all_providers()}"

  # Few properties that might have an impact on performances (provided by MS)
  options = SessionOptions()
  options.intra_op_num_threads = 1
  options.graph_optimization_level = GraphOptimizationLevel.ORT_ENABLE_ALL

  # Load the model as a graph and prepare the CPU backend 
  session = InferenceSession(model_path, options, providers=[provider])
  session.disable_fallback()
    
  return session

# %%
from transformers.convert_graph_to_onnx import quantize, optimize

# Optimize the ONNX model
optimized_model_path = optimize(Path("onnx/bert-base-uncased-SST-2.onnx"))

# Quantize the previously optimized ONNX
quantized_model_path = quantize(Path("onnx/bert-base-uncased-SST-2-optimized.onnx"))

# Then you just have to load through ONNX runtime
quantized_model_onnx = create_model_for_provider(quantized_model_path.as_posix(), "CPUExecutionProvider")
# Out:
# Optimized model has been written at onnx/bert-base-uncased-SST-2-optimized.onnx: ✔
# /!\ Optimized model contains hardware specific operators which might not be portable. /!\
# 2022-02-14 10:49:53 [WARNING] onnxruntime.quantization.quantize is deprecated.
#          Please use quantize_static for static quantization, quantize_dynamic for dynamic quantization.
# As of onnxruntime 1.4.0, models larger than 2GB will fail to quantize due to protobuf constraint.
# This limitation will be removed in the next release of onnxruntime.
# 2022-02-14 10:49:58 [INFO] Quantization parameters for tensor:"239" not specified
# 2022-02-14 10:49:59 [INFO] Quantization parameters for tensor:"298" not specified
# 2022-02-14 10:49:59 [INFO] Quantization parameters for tensor:"277" not specified
# 2022-02-14 10:49:59 [INFO] Quantization parameters for tensor:"312" not specified
# 2022-02-14 10:49:59 [INFO] Quantization parameters for tensor:"327" not specified
# 2022-02-14 10:49:59 [INFO] Quantization parameters for tensor:"338" not specified
# 2022-02-14 10:49:59 [INFO] Quantization parameters for tensor:"353" not specified
# 2022-02-14 10:50:00 [INFO] Quantization parameters for tensor:"412" not specified
# 2022-02-14 10:50:00 [INFO] Quantization parameters for tensor:"391" not specified
# 2022-02-14 10:50:00 [INFO] Quantization parameters for tensor:"426" not specified
# 2022-02-14 10:50:00 [INFO] Quantization parameters for tensor:"441" not specified
# 2022-02-14 10:50:00 [INFO] Quantization parameters for tensor:"452" not specified
# 2022-02-14 10:50:00 [INFO] Quantization parameters for tensor:"467" not specified
# 2022-02-14 10:50:01 [INFO] Quantization parameters for tensor:"526" not specified
# 2022-02-14 10:50:01 [INFO] Quantization parameters for tensor:"505" not specified
# 2022-02-14 10:50:01 [INFO] Quantization parameters for tensor:"540" not specified
# 2022-02-14 10:50:01 [INFO] Quantization parameters for tensor:"555" not specified
# 2022-02-14 10:50:01 [INFO] Quantization parameters for tensor:"566" not specified
# 2022-02-14 10:50:01 [INFO] Quantization parameters for tensor:"581" not specified
# 2022-02-14 10:50:02 [INFO] Quantization parameters for tensor:"640" not specified
# 2022-02-14 10:50:02 [INFO] Quantization parameters for tensor:"619" not specified
# 2022-02-14 10:50:02 [INFO] Quantization parameters for tensor:"654" not specified
# 2022-02-14 10:50:02 [INFO] Quantization parameters for tensor:"669" not specified
# 2022-02-14 10:50:02 [INFO] Quantization parameters for tensor:"680" not specified
# 2022-02-14 10:50:02 [INFO] Quantization parameters for tensor:"695" not specified
# 2022-02-14 10:50:03 [INFO] Quantization parameters for tensor:"754" not specified
# 2022-02-14 10:50:03 [INFO] Quantization parameters for tensor:"733" not specified
# 2022-02-14 10:50:03 [INFO] Quantization parameters for tensor:"768" not specified
# 2022-02-14 10:50:03 [INFO] Quantization parameters for tensor:"783" not specified
# 2022-02-14 10:50:03 [INFO] Quantization parameters for tensor:"794" not specified
# 2022-02-14 10:50:03 [INFO] Quantization parameters for tensor:"809" not specified
# 2022-02-14 10:50:04 [INFO] Quantization parameters for tensor:"868" not specified
# 2022-02-14 10:50:04 [INFO] Quantization parameters for tensor:"847" not specified
# 2022-02-14 10:50:04 [INFO] Quantization parameters for tensor:"882" not specified
# 2022-02-14 10:50:04 [INFO] Quantization parameters for tensor:"897" not specified
# 2022-02-14 10:50:04 [INFO] Quantization parameters for tensor:"908" not specified
# 2022-02-14 10:50:04 [INFO] Quantization parameters for tensor:"923" not specified
# 2022-02-14 10:50:05 [INFO] Quantization parameters for tensor:"982" not specified
# 2022-02-14 10:50:05 [INFO] Quantization parameters for tensor:"961" not specified
# 2022-02-14 10:50:05 [INFO] Quantization parameters for tensor:"996" not specified
# 2022-02-14 10:50:05 [INFO] Quantization parameters for tensor:"1011" not specified
# 2022-02-14 10:50:05 [INFO] Quantization parameters for tensor:"1022" not specified
# 2022-02-14 10:50:05 [INFO] Quantization parameters for tensor:"1037" not specified
# 2022-02-14 10:50:06 [INFO] Quantization parameters for tensor:"1096" not specified
# 2022-02-14 10:50:06 [INFO] Quantization parameters for tensor:"1075" not specified
# 2022-02-14 10:50:06 [INFO] Quantization parameters for tensor:"1110" not specified
# 2022-02-14 10:50:06 [INFO] Quantization parameters for tensor:"1125" not specified
# 2022-02-14 10:50:06 [INFO] Quantization parameters for tensor:"1136" not specified
# 2022-02-14 10:50:06 [INFO] Quantization parameters for tensor:"1151" not specified
# 2022-02-14 10:50:07 [INFO] Quantization parameters for tensor:"1210" not specified
# 2022-02-14 10:50:07 [INFO] Quantization parameters for tensor:"1189" not specified
# 2022-02-14 10:50:07 [INFO] Quantization parameters for tensor:"1224" not specified
# 2022-02-14 10:50:07 [INFO] Quantization parameters for tensor:"1239" not specified
# 2022-02-14 10:50:07 [INFO] Quantization parameters for tensor:"1250" not specified
# 2022-02-14 10:50:07 [INFO] Quantization parameters for tensor:"1265" not specified
# 2022-02-14 10:50:08 [INFO] Quantization parameters for tensor:"1324" not specified
# 2022-02-14 10:50:08 [INFO] Quantization parameters for tensor:"1303" not specified
# 2022-02-14 10:50:08 [INFO] Quantization parameters for tensor:"1338" not specified
# 2022-02-14 10:50:08 [INFO] Quantization parameters for tensor:"1353" not specified
# 2022-02-14 10:50:08 [INFO] Quantization parameters for tensor:"1364" not specified
# 2022-02-14 10:50:08 [INFO] Quantization parameters for tensor:"1379" not specified
# 2022-02-14 10:50:09 [INFO] Quantization parameters for tensor:"1438" not specified
# 2022-02-14 10:50:09 [INFO] Quantization parameters for tensor:"1417" not specified
# 2022-02-14 10:50:09 [INFO] Quantization parameters for tensor:"1452" not specified
# 2022-02-14 10:50:09 [INFO] Quantization parameters for tensor:"1467" not specified
# 2022-02-14 10:50:09 [INFO] Quantization parameters for tensor:"1478" not specified
# 2022-02-14 10:50:09 [INFO] Quantization parameters for tensor:"1493" not specified
# 2022-02-14 10:50:10 [INFO] Quantization parameters for tensor:"1552" not specified
# 2022-02-14 10:50:10 [INFO] Quantization parameters for tensor:"1531" not specified
# 2022-02-14 10:50:10 [INFO] Quantization parameters for tensor:"1566" not specified
# 2022-02-14 10:50:10 [INFO] Quantization parameters for tensor:"1581" not specified
# 2022-02-14 10:50:10 [INFO] Quantization parameters for tensor:"1592" not specified
# Quantized model has been written at onnx/bert-base-uncased-SST-2-optimized-quantized.onnx: ✔

# %%
import os

print('ONNX full precision model size (MB):', os.path.getsize("onnx/bert-base-uncased-SST-2.onnx")/(1024*1024))
print('ONNX quantized model size (MB):', os.path.getsize("onnx/bert-base-uncased-SST-2-optimized-quantized.onnx")/(1024*1024))
# Out:
# ONNX full precision model size (MB): 417.7162866592407
# ONNX quantized model size (MB): 106.53940677642822

# %% [markdown]
# Preparing inputs for the ONNX model:

# %%
inputs_onnx = {
    'attention_mask': eval_dataset['attention_mask'],
    'input_ids': eval_dataset['input_ids'],
    'token_type_ids': eval_dataset['token_type_ids']
}

# %% [markdown]
# Let's start performing the benchmark.

# %%
import time 

start_time = time.time()
outputs_batch = quantized_model_onnx.run(None, inputs_onnx)
elapsed_time = time.time() - start_time

pred = np.argmax(np.array(outputs_batch[0]), axis=1) # compare it with the eval_dataset['label']
metric_quantized_onnx = np.sum(pred == np.array(eval_dataset['label']))/len(pred)

print(f"Quantized model obtained with {metric_name} of {metric_quantized_onnx}, time elapsed: {elapsed_time}")
# Out:
# Quantized model obtained with eval_accuracy of 0.92, time elapsed: 69.48547196388245

# %% [markdown]
# ### Non-quantized version

# %% [markdown]
# The time it takes for the ONNX-quantized model is twice longer than that of the Lpot-quantized model. And that was about *quantized* model, how about the *non-quantized* version? How much accuracy does it get?

# %%
tokenizer_std = AutoTokenizer.from_pretrained("textattack/bert-base-uncased-SST-2")
model_std = AutoModelForSequenceClassification.from_pretrained("textattack/bert-base-uncased-SST-2")
# Out:
# loading configuration file https://huggingface.co/textattack/bert-base-uncased-SST-2/resolve/main/config.json from cache at /root/.cache/huggingface/transformers/293ab95645c102b941dee443ccf73fb9b5b5a9706b9893f09b5f1941b1bd0c8b.32da30c4245b376f0c4fd55aaf1c536c5ef13f10c248390e0311fcb4ca48f475
# Model config BertConfig {
#   "_name_or_path": "textattack/bert-base-uncased-SST-2",
#   "architectures": [
#     "BertForSequenceClassification"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "finetuning_task": "sst-2",
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.16.2",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 30522
# }
#
# loading file https://huggingface.co/textattack/bert-base-uncased-SST-2/resolve/main/vocab.txt from cache at /root/.cache/huggingface/transformers/9c8dda35c85d8852699ae2daa805d96a9e139eb93ab411edd3e7de9ff27c131f.d789d64ebfe299b0e416afc4a169632f903f693095b4629a7ea271d5a0cf2c99
# loading file https://huggingface.co/textattack/bert-base-uncased-SST-2/resolve/main/tokenizer.json from cache at None
# loading file https://huggingface.co/textattack/bert-base-uncased-SST-2/resolve/main/added_tokens.json from cache at None
# loading file https://huggingface.co/textattack/bert-base-uncased-SST-2/resolve/main/special_tokens_map.json from cache at /root/.cache/huggingface/transformers/c7c9b9c5d8bab3ba2ddaa08b138aa385f9790f30e8dce3bfe47e3f10bd97f4ad.dd8bd9bfd3664b530ea4e645105f557769387b3da9f79bdb55ed556bdd80611d
# loading file https://huggingface.co/textattack/bert-base-uncased-SST-2/resolve/main/tokenizer_config.json from cache at /root/.cache/huggingface/transformers/b0a5f8537502519294ee167d172bf5daff91c9277ffc722e9f46d6c8c05d2f55.76ea01b4b85ac16e2cec55c398cba7a943d89ab21dfdd973f6630a152e4b9aed
# loading configuration file https://huggingface.co/textattack/bert-base-uncased-SST-2/resolve/main/config.json from cache at /root/.cache/huggingface/transformers/293ab95645c102b941dee443ccf73fb9b5b5a9706b9893f09b5f1941b1bd0c8b.32da30c4245b376f0c4fd55aaf1c536c5ef13f10c248390e0311fcb4ca48f475
# Model config BertConfig {
#   "_name_or_path": "textattack/bert-base-uncased-SST-2",
#   "architectures": [
#     "BertForSequenceClassification"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "finetuning_task": "sst-2",
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.16.2",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 30522
# }
#
# loading configuration file https://huggingface.co/textattack/bert-base-uncased-SST-2/resolve/main/config.json from cache at /root/.cache/huggingface/transformers/293ab95645c102b941dee443ccf73fb9b5b5a9706b9893f09b5f1941b1bd0c8b.32da30c4245b376f0c4fd55aaf1c536c5ef13f10c248390e0311fcb4ca48f475
# Model config BertConfig {
#   "_name_or_path": "textattack/bert-base-uncased-SST-2",
#   "architectures": [
#     "BertForSequenceClassification"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "finetuning_task": "sst-2",
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.16.2",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 30522
# }
#
# loading configuration file https://huggingface.co/textattack/bert-base-uncased-SST-2/resolve/main/config.json from cache at /root/.cache/huggingface/transformers/293ab95645c102b941dee443ccf73fb9b5b5a9706b9893f09b5f1941b1bd0c8b.32da30c4245b376f0c4fd55aaf1c536c5ef13f10c248390e0311fcb4ca48f475
# Model config BertConfig {
#   "_name_or_path": "textattack/bert-base-uncased-SST-2",
#   "architectures": [
#     "BertForSequenceClassification"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "finetuning_task": "sst-2",
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.16.2",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 30522
# }
#
# loading weights file https://huggingface.co/textattack/bert-base-uncased-SST-2/resolve/main/pytorch_model.bin from cache at /root/.cache/huggingface/transformers/a7511de9d84e49d590d1debe392368a67a14cccc4bde4f72d766705702d2edd9.495764b52432aefa3c4d3988b595993be3f3d1e407c2cb9f3d5eb4ff4e886d1d
# All model checkpoint weights were used when initializing BertForSequenceClassification.
#
# All the weights of BertForSequenceClassification were initialized from the model checkpoint at textattack/bert-base-uncased-SST-2.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use BertForSequenceClassification for predictions without further training.

# %%
trainer_std = Trainer(
            model=model_std,
            eval_dataset=eval_dataset,
            compute_metrics=compute_metrics,
            tokenizer=tokenizer_std,
            data_collator=data_collator,
        )

start_time = time.time()
metric_std = take_eval_steps(model_std, trainer_std, metric_name)
elapsed_time = time.time() - start_time
print(f"Non-quantized model obtained with {metric_name} of {metric_std}, time elapsed: {elapsed_time}")
# Out:
# No `TrainingArguments` passed, using `output_dir=tmp_trainer`.
# PyTorch: setting up devices
# The default value for the training argument `--report_to` will change in v5 (from all installed integrations to none). In v5, you will need to use `--report_to all` to get the same behavior as now. You should start updating your code and make this info disappear :-).
# The following columns in the evaluation set  don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: idx, sentence.
# ***** Running Evaluation *****
#   Num examples = 200
#   Batch size = 8
#     <div>
#
#       <progress value='25' max='25' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [25/25 01:17]
#     </div>
# {'accuracy': 0.915}
# Non-quantized model obtained with eval_accuracy of 0.915, time elapsed: 80.45638847351074

# %% [markdown]
# From the results, we see that the Lpot-quantized model offers the best performance when doing inference on the evaluation set. However, depending on the CPU that is currently in use, this percentage number can vary. A good thing is that the evaluation accuracy remains the same between all models. A summary table of the results can be found below.

# %% [markdown]
# .|Lpot-quantization |ONNX-quantization |Baseline
# -----|-----|-----|-----
# *Accuracy*|0.915|0.915|0.915
# *Inference time*|10.58|22.27|20.73

# %% [markdown]
# ## 3. Quantization - Summarization 🤏

# %% [markdown]
# For now, let us pay attention to another famous NLP task - <i>summarization</i>. The question remains the same: How fast the model can get with Optimum?

# %% [markdown]
# For the *quantized* version, we have the following:

# %%
from transformers import AutoModelForSeq2SeqLM, AutoTokenizer, Seq2SeqTrainer, Seq2SeqTrainingArguments # Sequence-to-sequence language modelling

# %% [markdown]
# Following the same sequence as before, let's first have a look at the quantized model before checking out the non-quantized model. We first create some global variables to config the model.

# %%
# !pip install sacrebleu
# Out:
# Collecting sacrebleu
#   Downloading sacrebleu-2.0.0-py3-none-any.whl (90 kB)
#      |████████████████████████████████| 90 kB 6.9 MB/s
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.7/dist-packages (from sacrebleu) (0.8.9)
# Collecting colorama
#   Downloading colorama-0.4.4-py2.py3-none-any.whl (16 kB)
# Collecting portalocker
#   Downloading portalocker-2.3.2-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: regex in /usr/local/lib/python3.7/dist-packages (from sacrebleu) (2019.12.20)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from sacrebleu) (1.19.5)
# Installing collected packages: portalocker, colorama, sacrebleu
# Successfully installed colorama-0.4.4 portalocker-2.3.2 sacrebleu-2.0.0

# %%
model_name = "sshleifer/distilbart-cnn-12-6"
# config_path = "content/"
task = "summarization"
padding = "max_length"
max_seq_length = 128 
max_eval_samples = 8
metric_name = "eval_score"
dataset = load_dataset("cnn_dailymail",
                       '3.0.0',
                       split="validation[:5%]") # 5% of the validation data
metric = load_metric("sacrebleu")
data_collator = default_data_collator
sentence1_key, sentence2_key = "article", None
# Out:
# Downloading:   0%|          | 0.00/3.51k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.61k [00:00<?, ?B/s]
# Downloading and preparing dataset cnn_dailymail/3.0.0 (download: 558.32 MiB, generated: 1.28 GiB, post-processed: Unknown size, total: 1.82 GiB) to /root/.cache/huggingface/datasets/cnn_dailymail/3.0.0/3.0.0/3cb851bf7cf5826e45d49db2863f627cba583cbc32342df7349dfe6c38060234...
#   0%|          | 0/5 [00:00<?, ?it/s]
# Downloading:   0%|          | 0.00/159M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/376M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/572k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/12.3M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/661k [00:00<?, ?B/s]
#   0%|          | 0/5 [00:00<?, ?it/s]
# 0 examples [00:00, ? examples/s]
# 0 examples [00:00, ? examples/s]
# 0 examples [00:00, ? examples/s]
# Dataset cnn_dailymail downloaded and prepared to /root/.cache/huggingface/datasets/cnn_dailymail/3.0.0/3.0.0/3cb851bf7cf5826e45d49db2863f627cba583cbc32342df7349dfe6c38060234. Subsequent calls will reuse this data.
# Downloading:   0%|          | 0.00/2.36k [00:00<?, ?B/s]

# %% [markdown]
# ### Inc (intel neural compressor) quantization

# %% [markdown]
# Note that the evaluation sample for quantization tuning is very small (8). We can increase this number; however, it can be the case that quantization doesn't find a good model that matches the accuracy of the baseline model.

# %% [markdown]
# IncQuantizer doesn't come with a sequence-to-sequence class, hence we create one as in the cell below

# %%
class IncQuantizerForSequenceToSequenceLM(IncQuantizer):
  TRANSFORMERS_AUTO_CLASS = AutoModelForSeq2SeqLM

# %% [markdown]
# Initiate the quantizer:

# %%
# Don't forget to upload 'quantization.yml' before running this line
quantizer = IncQuantizerForSequenceToSequenceLM.from_config(
    model_name_or_path="sshleifer/distilbart-cnn-12-6",
    inc_config="quantization.yml",
)
# Out:
# https://huggingface.co/sshleifer/distilbart-cnn-12-6/resolve/main/tokenizer_config.json not found in cache or force_download set to True, downloading to /root/.cache/huggingface/transformers/tmpihnl1us6
# Downloading:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# storing https://huggingface.co/sshleifer/distilbart-cnn-12-6/resolve/main/tokenizer_config.json in cache at /root/.cache/huggingface/transformers/f5316f64f9716436994a7ad76a354dc20ecb2dd74eb61d278f103a9c8b80291f.67d01b18f2079bd75eac0b2f2e7235768c7f26bd728e7a855a1c5acae01a91a8
# creating metadata file for /root/.cache/huggingface/transformers/f5316f64f9716436994a7ad76a354dc20ecb2dd74eb61d278f103a9c8b80291f.67d01b18f2079bd75eac0b2f2e7235768c7f26bd728e7a855a1c5acae01a91a8
# https://huggingface.co/sshleifer/distilbart-cnn-12-6/resolve/main/config.json not found in cache or force_download set to True, downloading to /root/.cache/huggingface/transformers/tmp848gpdvi
# Downloading:   0%|          | 0.00/1.76k [00:00<?, ?B/s]
# storing https://huggingface.co/sshleifer/distilbart-cnn-12-6/resolve/main/config.json in cache at /root/.cache/huggingface/transformers/adac95cf641be69365b3dd7fe00d4114b3c7c77fb0572931db31a92d4995053b.a50597c2c8b540e8d07e03ca4d58bf615a365f134fb10ca988f4f67881789178
# creating metadata file for /root/.cache/huggingface/transformers/adac95cf641be69365b3dd7fe00d4114b3c7c77fb0572931db31a92d4995053b.a50597c2c8b540e8d07e03ca4d58bf615a365f134fb10ca988f4f67881789178
# loading configuration file https://huggingface.co/sshleifer/distilbart-cnn-12-6/resolve/main/config.json from cache at /root/.cache/huggingface/transformers/adac95cf641be69365b3dd7fe00d4114b3c7c77fb0572931db31a92d4995053b.a50597c2c8b540e8d07e03ca4d58bf615a365f134fb10ca988f4f67881789178
# Model config BartConfig {
#   "_name_or_path": "sshleifer/distilbart-cnn-12-6",
#   "_num_labels": 3,
#   "activation_dropout": 0.0,
#   "activation_function": "gelu",
#   "add_bias_logits": false,
#   "add_final_layer_norm": false,
#   "architectures": [
#     "BartForConditionalGeneration"
#   ],
#   "attention_dropout": 0.0,
#   "bos_token_id": 0,
#   "classif_dropout": 0.0,
#   "classifier_dropout": 0.0,
#   "d_model": 1024,
#   "decoder_attention_heads": 16,
#   "decoder_ffn_dim": 4096,
#   "decoder_layerdrop": 0.0,
#   "decoder_layers": 6,
#   "decoder_start_token_id": 2,
#   "dropout": 0.1,
#   "early_stopping": true,
#   "encoder_attention_heads": 16,
#   "encoder_ffn_dim": 4096,
#   "encoder_layerdrop": 0.0,
#   "encoder_layers": 12,
#   "eos_token_id": 2,
#   "extra_pos_embeddings": 2,
#   "force_bos_token_to_be_generated": true,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "gradient_checkpointing": false,
#   "id2label": {
#     "0": "LABEL_0",
#     "1": "LABEL_1",
#     "2": "LABEL_2"
#   },
#   "init_std": 0.02,
#   "is_encoder_decoder": true,
#   "label2id": {
#     "LABEL_0": 0,
#     "LABEL_1": 1,
#     "LABEL_2": 2
#   },
#   "length_penalty": 2.0,
#   "max_length": 142,
#   "max_position_embeddings": 1024,
#   "min_length": 56,
#   "model_type": "bart",
#   "no_repeat_ngram_size": 3,
#   "normalize_before": false,
#   "normalize_embedding": true,
#   "num_beams": 4,
#   "num_hidden_layers": 12,
#   "output_past": true,
#   "pad_token_id": 1,
#   "prefix": " ",
#   "replacing_rate": 0,
#   "scale_embedding": false,
#   "static_position_embeddings": false,
#   "student_decoder_layers": null,
#   "student_encoder_layers": null,
#   "task_specific_params": {
#     "summarization": {
#       "early_stopping": true,
#       "length_penalty": 2.0,
#       "max_length": 142,
#       "min_length": 56,
#       "no_repeat_ngram_size": 3,
#       "num_beams": 4
#     }
#   },
#   "transformers_version": "4.16.2",
#   "use_cache": true,
#   "vocab_size": 50264
# }
#
# https://huggingface.co/sshleifer/distilbart-cnn-12-6/resolve/main/vocab.json not found in cache or force_download set to True, downloading to /root/.cache/huggingface/transformers/tmpw5zzy0x4
# Downloading:   0%|          | 0.00/878k [00:00<?, ?B/s]
# storing https://huggingface.co/sshleifer/distilbart-cnn-12-6/resolve/main/vocab.json in cache at /root/.cache/huggingface/transformers/9951e68693b9a7c583ae677e9cb53c02715d9bd0311a78706401372653cdea0a.647b4548b6d9ea817e82e7a9231a320231a1c9ea24053cc9e758f3fe68216f05
# creating metadata file for /root/.cache/huggingface/transformers/9951e68693b9a7c583ae677e9cb53c02715d9bd0311a78706401372653cdea0a.647b4548b6d9ea817e82e7a9231a320231a1c9ea24053cc9e758f3fe68216f05
# https://huggingface.co/sshleifer/distilbart-cnn-12-6/resolve/main/merges.txt not found in cache or force_download set to True, downloading to /root/.cache/huggingface/transformers/tmp6qch1dy3
# Downloading:   0%|          | 0.00/446k [00:00<?, ?B/s]
# storing https://huggingface.co/sshleifer/distilbart-cnn-12-6/resolve/main/merges.txt in cache at /root/.cache/huggingface/transformers/7588c8d398d659b230a038240cc023f67b6848117d2999f06ab625af7bfc7ec1.5d12962c5ee615a4c803841266e9c3be9a691a924f72d395d3a6c6c81157788b
# creating metadata file for /root/.cache/huggingface/transformers/7588c8d398d659b230a038240cc023f67b6848117d2999f06ab625af7bfc7ec1.5d12962c5ee615a4c803841266e9c3be9a691a924f72d395d3a6c6c81157788b
# loading file https://huggingface.co/sshleifer/distilbart-cnn-12-6/resolve/main/vocab.json from cache at /root/.cache/huggingface/transformers/9951e68693b9a7c583ae677e9cb53c02715d9bd0311a78706401372653cdea0a.647b4548b6d9ea817e82e7a9231a320231a1c9ea24053cc9e758f3fe68216f05
# loading file https://huggingface.co/sshleifer/distilbart-cnn-12-6/resolve/main/merges.txt from cache at /root/.cache/huggingface/transformers/7588c8d398d659b230a038240cc023f67b6848117d2999f06ab625af7bfc7ec1.5d12962c5ee615a4c803841266e9c3be9a691a924f72d395d3a6c6c81157788b
# loading file https://huggingface.co/sshleifer/distilbart-cnn-12-6/resolve/main/tokenizer.json from cache at None
# loading file https://huggingface.co/sshleifer/distilbart-cnn-12-6/resolve/main/added_tokens.json from cache at None
# loading file https://huggingface.co/sshleifer/distilbart-cnn-12-6/resolve/main/special_tokens_map.json from cache at None
# loading file https://huggingface.co/sshleifer/distilbart-cnn-12-6/resolve/main/tokenizer_config.json from cache at /root/.cache/huggingface/transformers/f5316f64f9716436994a7ad76a354dc20ecb2dd74eb61d278f103a9c8b80291f.67d01b18f2079bd75eac0b2f2e7235768c7f26bd728e7a855a1c5acae01a91a8
# loading configuration file https://huggingface.co/sshleifer/distilbart-cnn-12-6/resolve/main/config.json from cache at /root/.cache/huggingface/transformers/adac95cf641be69365b3dd7fe00d4114b3c7c77fb0572931db31a92d4995053b.a50597c2c8b540e8d07e03ca4d58bf615a365f134fb10ca988f4f67881789178
# Model config BartConfig {
#   "_name_or_path": "sshleifer/distilbart-cnn-12-6",
#   "_num_labels": 3,
#   "activation_dropout": 0.0,
#   "activation_function": "gelu",
#   "add_bias_logits": false,
#   "add_final_layer_norm": false,
#   "architectures": [
#     "BartForConditionalGeneration"
#   ],
#   "attention_dropout": 0.0,
#   "bos_token_id": 0,
#   "classif_dropout": 0.0,
#   "classifier_dropout": 0.0,
#   "d_model": 1024,
#   "decoder_attention_heads": 16,
#   "decoder_ffn_dim": 4096,
#   "decoder_layerdrop": 0.0,
#   "decoder_layers": 6,
#   "decoder_start_token_id": 2,
#   "dropout": 0.1,
#   "early_stopping": true,
#   "encoder_attention_heads": 16,
#   "encoder_ffn_dim": 4096,
#   "encoder_layerdrop": 0.0,
#   "encoder_layers": 12,
#   "eos_token_id": 2,
#   "extra_pos_embeddings": 2,
#   "force_bos_token_to_be_generated": true,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "gradient_checkpointing": false,
#   "id2label": {
#     "0": "LABEL_0",
#     "1": "LABEL_1",
#     "2": "LABEL_2"
#   },
#   "init_std": 0.02,
#   "is_encoder_decoder": true,
#   "label2id": {
#     "LABEL_0": 0,
#     "LABEL_1": 1,
#     "LABEL_2": 2
#   },
#   "length_penalty": 2.0,
#   "max_length": 142,
#   "max_position_embeddings": 1024,
#   "min_length": 56,
#   "model_type": "bart",
#   "no_repeat_ngram_size": 3,
#   "normalize_before": false,
#   "normalize_embedding": true,
#   "num_beams": 4,
#   "num_hidden_layers": 12,
#   "output_past": true,
#   "pad_token_id": 1,
#   "prefix": " ",
#   "replacing_rate": 0,
#   "scale_embedding": false,
#   "static_position_embeddings": false,
#   "student_decoder_layers": null,
#   "student_encoder_layers": null,
#   "task_specific_params": {
#     "summarization": {
#       "early_stopping": true,
#       "length_penalty": 2.0,
#       "max_length": 142,
#       "min_length": 56,
#       "no_repeat_ngram_size": 3,
#       "num_beams": 4
#     }
#   },
#   "transformers_version": "4.16.2",
#   "use_cache": true,
#   "vocab_size": 50264
# }
#
# loading configuration file https://huggingface.co/sshleifer/distilbart-cnn-12-6/resolve/main/config.json from cache at /root/.cache/huggingface/transformers/adac95cf641be69365b3dd7fe00d4114b3c7c77fb0572931db31a92d4995053b.a50597c2c8b540e8d07e03ca4d58bf615a365f134fb10ca988f4f67881789178
# Model config BartConfig {
#   "_name_or_path": "sshleifer/distilbart-cnn-12-6",
#   "_num_labels": 3,
#   "activation_dropout": 0.0,
#   "activation_function": "gelu",
#   "add_bias_logits": false,
#   "add_final_layer_norm": false,
#   "architectures": [
#     "BartForConditionalGeneration"
#   ],
#   "attention_dropout": 0.0,
#   "bos_token_id": 0,
#   "classif_dropout": 0.0,
#   "classifier_dropout": 0.0,
#   "d_model": 1024,
#   "decoder_attention_heads": 16,
#   "decoder_ffn_dim": 4096,
#   "decoder_layerdrop": 0.0,
#   "decoder_layers": 6,
#   "decoder_start_token_id": 2,
#   "dropout": 0.1,
#   "early_stopping": true,
#   "encoder_attention_heads": 16,
#   "encoder_ffn_dim": 4096,
#   "encoder_layerdrop": 0.0,
#   "encoder_layers": 12,
#   "eos_token_id": 2,
#   "extra_pos_embeddings": 2,
#   "force_bos_token_to_be_generated": true,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "gradient_checkpointing": false,
#   "id2label": {
#     "0": "LABEL_0",
#     "1": "LABEL_1",
#     "2": "LABEL_2"
#   },
#   "init_std": 0.02,
#   "is_encoder_decoder": true,
#   "label2id": {
#     "LABEL_0": 0,
#     "LABEL_1": 1,
#     "LABEL_2": 2
#   },
#   "length_penalty": 2.0,
#   "max_length": 142,
#   "max_position_embeddings": 1024,
#   "min_length": 56,
#   "model_type": "bart",
#   "no_repeat_ngram_size": 3,
#   "normalize_before": false,
#   "normalize_embedding": true,
#   "num_beams": 4,
#   "num_hidden_layers": 12,
#   "output_past": true,
#   "pad_token_id": 1,
#   "prefix": " ",
#   "replacing_rate": 0,
#   "scale_embedding": false,
#   "static_position_embeddings": false,
#   "student_decoder_layers": null,
#   "student_encoder_layers": null,
#   "task_specific_params": {
#     "summarization": {
#       "early_stopping": true,
#       "length_penalty": 2.0,
#       "max_length": 142,
#       "min_length": 56,
#       "no_repeat_ngram_size": 3,
#       "num_beams": 4
#     }
#   },
#   "transformers_version": "4.16.2",
#   "use_cache": true,
#   "vocab_size": 50264
# }
#
# loading configuration file https://huggingface.co/sshleifer/distilbart-cnn-12-6/resolve/main/config.json from cache at /root/.cache/huggingface/transformers/adac95cf641be69365b3dd7fe00d4114b3c7c77fb0572931db31a92d4995053b.a50597c2c8b540e8d07e03ca4d58bf615a365f134fb10ca988f4f67881789178
# Model config BartConfig {
#   "_name_or_path": "sshleifer/distilbart-cnn-12-6",
#   "_num_labels": 3,
#   "activation_dropout": 0.0,
#   "activation_function": "gelu",
#   "add_bias_logits": false,
#   "add_final_layer_norm": false,
#   "architectures": [
#     "BartForConditionalGeneration"
#   ],
#   "attention_dropout": 0.0,
#   "bos_token_id": 0,
#   "classif_dropout": 0.0,
#   "classifier_dropout": 0.0,
#   "d_model": 1024,
#   "decoder_attention_heads": 16,
#   "decoder_ffn_dim": 4096,
#   "decoder_layerdrop": 0.0,
#   "decoder_layers": 6,
#   "decoder_start_token_id": 2,
#   "dropout": 0.1,
#   "early_stopping": true,
#   "encoder_attention_heads": 16,
#   "encoder_ffn_dim": 4096,
#   "encoder_layerdrop": 0.0,
#   "encoder_layers": 12,
#   "eos_token_id": 2,
#   "extra_pos_embeddings": 2,
#   "force_bos_token_to_be_generated": true,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "gradient_checkpointing": false,
#   "id2label": {
#     "0": "LABEL_0",
#     "1": "LABEL_1",
#     "2": "LABEL_2"
#   },
#   "init_std": 0.02,
#   "is_encoder_decoder": true,
#   "label2id": {
#     "LABEL_0": 0,
#     "LABEL_1": 1,
#     "LABEL_2": 2
#   },
#   "length_penalty": 2.0,
#   "max_length": 142,
#   "max_position_embeddings": 1024,
#   "min_length": 56,
#   "model_type": "bart",
#   "no_repeat_ngram_size": 3,
#   "normalize_before": false,
#   "normalize_embedding": true,
#   "num_beams": 4,
#   "num_hidden_layers": 12,
#   "output_past": true,
#   "pad_token_id": 1,
#   "prefix": " ",
#   "replacing_rate": 0,
#   "scale_embedding": false,
#   "static_position_embeddings": false,
#   "student_decoder_layers": null,
#   "student_encoder_layers": null,
#   "task_specific_params": {
#     "summarization": {
#       "early_stopping": true,
#       "length_penalty": 2.0,
#       "max_length": 142,
#       "min_length": 56,
#       "no_repeat_ngram_size": 3,
#       "num_beams": 4
#     }
#   },
#   "transformers_version": "4.16.2",
#   "use_cache": true,
#   "vocab_size": 50264
# }
#
# https://huggingface.co/sshleifer/distilbart-cnn-12-6/resolve/main/pytorch_model.bin not found in cache or force_download set to True, downloading to /root/.cache/huggingface/transformers/tmp86ckuxkm
# Downloading:   0%|          | 0.00/1.14G [00:00<?, ?B/s]
# storing https://huggingface.co/sshleifer/distilbart-cnn-12-6/resolve/main/pytorch_model.bin in cache at /root/.cache/huggingface/transformers/b336fa0b874ea92e3e22f07a7e6f8fa9da01221759c33abeb2679d6d98fe7755.585965cf7e82e4536033cd21d76c486af3d6b1c2a34b3a847840d4e7fe9d8844
# creating metadata file for /root/.cache/huggingface/transformers/b336fa0b874ea92e3e22f07a7e6f8fa9da01221759c33abeb2679d6d98fe7755.585965cf7e82e4536033cd21d76c486af3d6b1c2a34b3a847840d4e7fe9d8844
# loading weights file https://huggingface.co/sshleifer/distilbart-cnn-12-6/resolve/main/pytorch_model.bin from cache at /root/.cache/huggingface/transformers/b336fa0b874ea92e3e22f07a7e6f8fa9da01221759c33abeb2679d6d98fe7755.585965cf7e82e4536033cd21d76c486af3d6b1c2a34b3a847840d4e7fe9d8844
# All model checkpoint weights were used when initializing BartForConditionalGeneration.
#
# All the weights of BartForConditionalGeneration were initialized from the model checkpoint at sshleifer/distilbart-cnn-12-6.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use BartForConditionalGeneration for predictions without further training.

# %%
tokenizer = quantizer.tokenizer
model = quantizer.model # BartForConditionalGeneration

# %% [markdown]
# Having the tokenizer, define a preprocessing function for the inputs

# %%
def preprocess_function(examples):
  result = tokenizer(examples['article'],
                     padding=padding,
                     max_length=max_seq_length,
                     truncation=True)
  
  ground_truth = tokenizer(examples['highlights'],
                     padding=padding,
                     max_length=max_seq_length,
                     truncation=True)

  result["labels"] = ground_truth["input_ids"]
  result["label_ids"] = ground_truth["input_ids"]

  return result

def print_article(examples):
  print(examples['article'])

eval_dataset = dataset.map(preprocess_function, batched=True)
eval_dataset = eval_dataset.select(range(max_eval_samples))
# Out:
#   0%|          | 0/1 [00:00<?, ?ba/s]

# %%
# The lines below test how the model outputs
# dummy_input = tokenizer("summarize: " + eval_dataset[0]['article'], return_tensors='pt', 
#                         max_length=128, truncation=True)
# dummy_output = model.generate(dummy_input["input_ids"], max_length=150, min_length=40,
#                               length_penalty=2.0, num_beams=4, early_stopping=True)

# %%
# tokenizer.decode(dummy_output[0])

# %% [markdown]
# Define a *compute_metric* functions that serve as the inputs for the Seq2SeqTrainer class.

# %%
def compute_metrics(p: EvalPrediction):
  label_ids = p.label_ids
  pred_ids = p.predictions
  pred_str = tokenizer.batch_decode(pred_ids, skip_special_tokens=True)
  label_ids[label_ids == -100] = tokenizer.pad_token_id
  label_str = tokenizer.batch_decode(label_ids, skip_special_tokens=True)
  label_str = [[label] for label in label_str]

  bleu_output = metric.compute(predictions=pred_str, references=label_str)
  return bleu_output

# %%
training_args = Seq2SeqTrainingArguments(
    predict_with_generate=True,
    output_dir="content/"
)

trainer = Seq2SeqTrainer(
            model=model,
            args=training_args,
            eval_dataset=eval_dataset,
            compute_metrics=compute_metrics,
            tokenizer=tokenizer,
            data_collator=data_collator,
        )
# Out:
# PyTorch: setting up devices
# The default value for the training argument `--report_to` will change in v5 (from all installed integrations to none). In v5, you will need to use `--report_to all` to get the same behavior as now. You should start updating your code and make this info disappear :-).

# %%
def take_eval_steps(model, trainer, metric_name):
  trainer.model = model
  metrics = trainer.evaluate(max_length=max_seq_length, num_beams=4)
  return metrics[metric_name]

def eval_func(model):
  return take_eval_steps(model, trainer, metric_name)

# %%
quantizer.eval_func = eval_func
q_model = quantizer.fit_dynamic()
# Out:
# 2022-02-14 11:06:00 [INFO] Pass query framework capability elapsed time: 6.03 ms
# 2022-02-14 11:06:00 [INFO] Get FP32 model baseline.
# The following columns in the evaluation set  don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: highlights, id, article.
# ***** Running Evaluation *****
#   Num examples = 8
#   Batch size = 8
#     <div>
#
#       <progress value='20' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1/1 12:28]
#     </div>
# Trainer is attempting to log a value of "[98, 34, 23, 17]" of type <class 'list'> for key "eval/counts" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "[434, 426, 418, 410]" of type <class 'list'> for key "eval/totals" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "[22.580645161290324, 7.981220657276995, 5.502392344497608, 4.146341463414634]" of type <class 'list'> for key "eval/precisions" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# 2022-02-14 11:06:41 [INFO] Save tuning history to /content/nc_workspace/2022-02-14_10-00-09/./history.snapshot.
# 2022-02-14 11:06:41 [INFO] FP32 baseline is: [Accuracy: 8.0077, Duration (seconds): 41.0515]
# 2022-02-14 11:06:51 [INFO] |*****Mixed Precision Statistics*****|
# 2022-02-14 11:06:51 [INFO] +--------------+-----------+---------+
# 2022-02-14 11:06:51 [INFO] |   Op Type    |   Total   |   INT8  |
# 2022-02-14 11:06:51 [INFO] +--------------+-----------+---------+
# 2022-02-14 11:06:51 [INFO] |    Linear    |    133    |   133   |
# 2022-02-14 11:06:51 [INFO] +--------------+-----------+---------+
# 2022-02-14 11:06:51 [INFO] Pass quantize model elapsed time: 9971.15 ms
# The following columns in the evaluation set  don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: highlights, id, article.
# ***** Running Evaluation *****
#   Num examples = 8
#   Batch size = 8
# Trainer is attempting to log a value of "[97, 31, 17, 8]" of type <class 'list'> for key "eval/counts" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "[470, 462, 454, 446]" of type <class 'list'> for key "eval/totals" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "[20.638297872340427, 6.70995670995671, 3.7444933920704844, 1.7937219730941705]" of type <class 'list'> for key "eval/precisions" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# 2022-02-14 11:07:21 [INFO] Tune 1 result is: [Accuracy (int8|fp32): 5.5225|8.0077, Duration (seconds) (int8|fp32): 29.7429|41.0515], Best tune result is: n/a
# 2022-02-14 11:07:21 [INFO] Save tuning history to /content/nc_workspace/2022-02-14_10-00-09/./history.snapshot.
# 2022-02-14 11:07:28 [INFO] |*******Mixed Precision Statistics*******|
# 2022-02-14 11:07:28 [INFO] +------------+---------+--------+--------+
# 2022-02-14 11:07:28 [INFO] |  Op Type   |  Total  |  INT8  |  FP32  |
# 2022-02-14 11:07:28 [INFO] +------------+---------+--------+--------+
# 2022-02-14 11:07:28 [INFO] |   Linear   |   133   |  132   |   1    |
# 2022-02-14 11:07:28 [INFO] +------------+---------+--------+--------+
# 2022-02-14 11:07:28 [INFO] Pass quantize model elapsed time: 7149.85 ms
# The following columns in the evaluation set  don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: highlights, id, article.
# ***** Running Evaluation *****
#   Num examples = 8
#   Batch size = 8
# Trainer is attempting to log a value of "[96, 28, 15, 8]" of type <class 'list'> for key "eval/counts" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "[454, 446, 438, 430]" of type <class 'list'> for key "eval/totals" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "[21.145374449339208, 6.278026905829597, 3.4246575342465753, 1.8604651162790697]" of type <class 'list'> for key "eval/precisions" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# 2022-02-14 11:08:01 [INFO] Tune 2 result is: [Accuracy (int8|fp32): 5.3929|8.0077, Duration (seconds) (int8|fp32): 32.8119|41.0515], Best tune result is: n/a
# 2022-02-14 11:08:01 [INFO] Save tuning history to /content/nc_workspace/2022-02-14_10-00-09/./history.snapshot.
# 2022-02-14 11:08:11 [INFO] |*******Mixed Precision Statistics*******|
# 2022-02-14 11:08:11 [INFO] +------------+---------+--------+--------+
# 2022-02-14 11:08:11 [INFO] |  Op Type   |  Total  |  INT8  |  FP32  |
# 2022-02-14 11:08:11 [INFO] +------------+---------+--------+--------+
# 2022-02-14 11:08:11 [INFO] |   Linear   |   133   |  132   |   1    |
# 2022-02-14 11:08:11 [INFO] +------------+---------+--------+--------+
# 2022-02-14 11:08:11 [INFO] Pass quantize model elapsed time: 10039.34 ms
# The following columns in the evaluation set  don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: highlights, id, article.
# ***** Running Evaluation *****
#   Num examples = 8
#   Batch size = 8
# Trainer is attempting to log a value of "[92, 33, 22, 14]" of type <class 'list'> for key "eval/counts" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "[468, 460, 452, 444]" of type <class 'list'> for key "eval/totals" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "[19.65811965811966, 7.173913043478261, 4.867256637168142, 3.1531531531531534]" of type <class 'list'> for key "eval/precisions" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# 2022-02-14 11:08:39 [INFO] Tune 3 result is: [Accuracy (int8|fp32): 6.8207|8.0077, Duration (seconds) (int8|fp32): 28.2314|41.0515], Best tune result is: n/a
# 2022-02-14 11:08:39 [INFO] Save tuning history to /content/nc_workspace/2022-02-14_10-00-09/./history.snapshot.
# 2022-02-14 11:08:49 [INFO] |*******Mixed Precision Statistics*******|
# 2022-02-14 11:08:49 [INFO] +------------+---------+--------+--------+
# 2022-02-14 11:08:49 [INFO] |  Op Type   |  Total  |  INT8  |  FP32  |
# 2022-02-14 11:08:49 [INFO] +------------+---------+--------+--------+
# 2022-02-14 11:08:49 [INFO] |   Linear   |   133   |  132   |   1    |
# 2022-02-14 11:08:49 [INFO] +------------+---------+--------+--------+
# 2022-02-14 11:08:49 [INFO] Pass quantize model elapsed time: 9673.42 ms
# The following columns in the evaluation set  don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: highlights, id, article.
# ***** Running Evaluation *****
#   Num examples = 8
#   Batch size = 8
# Trainer is attempting to log a value of "[92, 29, 16, 7]" of type <class 'list'> for key "eval/counts" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "[478, 470, 462, 454]" of type <class 'list'> for key "eval/totals" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "[19.246861924686193, 6.170212765957447, 3.463203463203463, 1.5418502202643172]" of type <class 'list'> for key "eval/precisions" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# 2022-02-14 11:09:22 [INFO] Tune 4 result is: [Accuracy (int8|fp32): 5.0182|8.0077, Duration (seconds) (int8|fp32): 33.1554|41.0515], Best tune result is: n/a
# 2022-02-14 11:09:22 [INFO] Save tuning history to /content/nc_workspace/2022-02-14_10-00-09/./history.snapshot.
# 2022-02-14 11:09:32 [INFO] |*******Mixed Precision Statistics*******|
# 2022-02-14 11:09:32 [INFO] +------------+---------+--------+--------+
# 2022-02-14 11:09:32 [INFO] |  Op Type   |  Total  |  INT8  |  FP32  |
# 2022-02-14 11:09:32 [INFO] +------------+---------+--------+--------+
# 2022-02-14 11:09:32 [INFO] |   Linear   |   133   |  132   |   1    |
# 2022-02-14 11:09:32 [INFO] +------------+---------+--------+--------+
# 2022-02-14 11:09:32 [INFO] Pass quantize model elapsed time: 9851.64 ms
# The following columns in the evaluation set  don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: highlights, id, article.
# ***** Running Evaluation *****
#   Num examples = 8
#   Batch size = 8
# Trainer is attempting to log a value of "[90, 25, 16, 10]" of type <class 'list'> for key "eval/counts" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "[452, 444, 436, 428]" of type <class 'list'> for key "eval/totals" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "[19.911504424778762, 5.63063063063063, 3.669724770642202, 2.336448598130841]" of type <class 'list'> for key "eval/precisions" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# 2022-02-14 11:10:01 [INFO] Tune 5 result is: [Accuracy (int8|fp32): 5.5682|8.0077, Duration (seconds) (int8|fp32): 28.8088|41.0515], Best tune result is: n/a
# 2022-02-14 11:10:01 [INFO] Save tuning history to /content/nc_workspace/2022-02-14_10-00-09/./history.snapshot.
# 2022-02-14 11:10:15 [INFO] |*******Mixed Precision Statistics*******|
# 2022-02-14 11:10:15 [INFO] +------------+---------+--------+--------+
# 2022-02-14 11:10:15 [INFO] |  Op Type   |  Total  |  INT8  |  FP32  |
# 2022-02-14 11:10:15 [INFO] +------------+---------+--------+--------+
# 2022-02-14 11:10:15 [INFO] |   Linear   |   133   |  132   |   1    |
# 2022-02-14 11:10:15 [INFO] +------------+---------+--------+--------+
# 2022-02-14 11:10:15 [INFO] Pass quantize model elapsed time: 14092.81 ms
# The following columns in the evaluation set  don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: highlights, id, article.
# ***** Running Evaluation *****
#   Num examples = 8
#   Batch size = 8
# Trainer is attempting to log a value of "[86, 23, 14, 7]" of type <class 'list'> for key "eval/counts" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "[430, 422, 414, 406]" of type <class 'list'> for key "eval/totals" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "[20.0, 5.450236966824645, 3.3816425120772946, 1.7241379310344827]" of type <class 'list'> for key "eval/precisions" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# 2022-02-14 11:10:43 [INFO] Tune 6 result is: [Accuracy (int8|fp32): 5.0210|8.0077, Duration (seconds) (int8|fp32): 27.9055|41.0515], Best tune result is: n/a
# 2022-02-14 11:10:43 [INFO] Save tuning history to /content/nc_workspace/2022-02-14_10-00-09/./history.snapshot.
# 2022-02-14 11:10:53 [INFO] |*******Mixed Precision Statistics*******|
# 2022-02-14 11:10:53 [INFO] +------------+---------+--------+--------+
# 2022-02-14 11:10:53 [INFO] |  Op Type   |  Total  |  INT8  |  FP32  |
# 2022-02-14 11:10:53 [INFO] +------------+---------+--------+--------+
# 2022-02-14 11:10:53 [INFO] |   Linear   |   133   |  132   |   1    |
# 2022-02-14 11:10:53 [INFO] +------------+---------+--------+--------+
# 2022-02-14 11:10:53 [INFO] Pass quantize model elapsed time: 10430.16 ms
# The following columns in the evaluation set  don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: highlights, id, article.
# ***** Running Evaluation *****
#   Num examples = 8
#   Batch size = 8
# Trainer is attempting to log a value of "[92, 28, 17, 10]" of type <class 'list'> for key "eval/counts" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "[456, 448, 440, 432]" of type <class 'list'> for key "eval/totals" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "[20.17543859649123, 6.25, 3.8636363636363638, 2.314814814814815]" of type <class 'list'> for key "eval/precisions" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# 2022-02-14 11:11:22 [INFO] Tune 7 result is: [Accuracy (int8|fp32): 5.7950|8.0077, Duration (seconds) (int8|fp32): 28.9695|41.0515], Best tune result is: n/a
# 2022-02-14 11:11:22 [INFO] Save tuning history to /content/nc_workspace/2022-02-14_10-00-09/./history.snapshot.
# 2022-02-14 11:11:32 [INFO] |*******Mixed Precision Statistics*******|
# 2022-02-14 11:11:32 [INFO] +------------+---------+--------+--------+
# 2022-02-14 11:11:32 [INFO] |  Op Type   |  Total  |  INT8  |  FP32  |
# 2022-02-14 11:11:32 [INFO] +------------+---------+--------+--------+
# 2022-02-14 11:11:32 [INFO] |   Linear   |   133   |  132   |   1    |
# 2022-02-14 11:11:32 [INFO] +------------+---------+--------+--------+
# 2022-02-14 11:11:32 [INFO] Pass quantize model elapsed time: 9679.82 ms
# The following columns in the evaluation set  don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: highlights, id, article.
# ***** Running Evaluation *****
#   Num examples = 8
#   Batch size = 8
# Trainer is attempting to log a value of "[91, 27, 16, 9]" of type <class 'list'> for key "eval/counts" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "[445, 437, 429, 421]" of type <class 'list'> for key "eval/totals" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "[20.44943820224719, 6.178489702517163, 3.7296037296037294, 2.137767220902613]" of type <class 'list'> for key "eval/precisions" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# 2022-02-14 11:12:00 [INFO] Tune 8 result is: [Accuracy (int8|fp32): 5.6337|8.0077, Duration (seconds) (int8|fp32): 28.0064|41.0515], Best tune result is: n/a
# 2022-02-14 11:12:00 [INFO] Save tuning history to /content/nc_workspace/2022-02-14_10-00-09/./history.snapshot.
# 2022-02-14 11:12:10 [INFO] |*******Mixed Precision Statistics*******|
# 2022-02-14 11:12:10 [INFO] +------------+---------+--------+--------+
# 2022-02-14 11:12:10 [INFO] |  Op Type   |  Total  |  INT8  |  FP32  |
# 2022-02-14 11:12:10 [INFO] +------------+---------+--------+--------+
# 2022-02-14 11:12:10 [INFO] |   Linear   |   133   |  132   |   1    |
# 2022-02-14 11:12:10 [INFO] +------------+---------+--------+--------+
# 2022-02-14 11:12:10 [INFO] Pass quantize model elapsed time: 9851.35 ms
# The following columns in the evaluation set  don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: highlights, id, article.
# ***** Running Evaluation *****
#   Num examples = 8
#   Batch size = 8
# Trainer is attempting to log a value of "[89, 30, 20, 12]" of type <class 'list'> for key "eval/counts" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "[454, 446, 438, 430]" of type <class 'list'> for key "eval/totals" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "[19.60352422907489, 6.726457399103139, 4.566210045662101, 2.7906976744186047]" of type <class 'list'> for key "eval/precisions" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# 2022-02-14 11:12:38 [INFO] Tune 9 result is: [Accuracy (int8|fp32): 6.4025|8.0077, Duration (seconds) (int8|fp32): 28.2156|41.0515], Best tune result is: n/a
# 2022-02-14 11:12:38 [INFO] Save tuning history to /content/nc_workspace/2022-02-14_10-00-09/./history.snapshot.
# 2022-02-14 11:12:48 [INFO] |*******Mixed Precision Statistics*******|
# 2022-02-14 11:12:48 [INFO] +------------+---------+--------+--------+
# 2022-02-14 11:12:48 [INFO] |  Op Type   |  Total  |  INT8  |  FP32  |
# 2022-02-14 11:12:48 [INFO] +------------+---------+--------+--------+
# 2022-02-14 11:12:48 [INFO] |   Linear   |   133   |  132   |   1    |
# 2022-02-14 11:12:48 [INFO] +------------+---------+--------+--------+
# 2022-02-14 11:12:48 [INFO] Pass quantize model elapsed time: 9892.88 ms
# The following columns in the evaluation set  don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: highlights, id, article.
# ***** Running Evaluation *****
#   Num examples = 8
#   Batch size = 8
# Trainer is attempting to log a value of "[94, 35, 21, 12]" of type <class 'list'> for key "eval/counts" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "[469, 461, 453, 445]" of type <class 'list'> for key "eval/totals" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "[20.042643923240938, 7.592190889370933, 4.635761589403973, 2.696629213483146]" of type <class 'list'> for key "eval/precisions" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# 2022-02-14 11:13:17 [INFO] Tune 10 result is: [Accuracy (int8|fp32): 6.6041|8.0077, Duration (seconds) (int8|fp32): 29.2047|41.0515], Best tune result is: n/a
# 2022-02-14 11:13:17 [INFO] Save tuning history to /content/nc_workspace/2022-02-14_10-00-09/./history.snapshot.
# 2022-02-14 11:13:27 [INFO] |*******Mixed Precision Statistics*******|
# 2022-02-14 11:13:27 [INFO] +------------+---------+--------+--------+
# 2022-02-14 11:13:27 [INFO] |  Op Type   |  Total  |  INT8  |  FP32  |
# 2022-02-14 11:13:27 [INFO] +------------+---------+--------+--------+
# 2022-02-14 11:13:27 [INFO] |   Linear   |   133   |  132   |   1    |
# 2022-02-14 11:13:27 [INFO] +------------+---------+--------+--------+
# 2022-02-14 11:13:27 [INFO] Pass quantize model elapsed time: 9733.78 ms
# The following columns in the evaluation set  don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: highlights, id, article.
# ***** Running Evaluation *****
#   Num examples = 8
#   Batch size = 8
# Trainer is attempting to log a value of "[100, 28, 14, 5]" of type <class 'list'> for key "eval/counts" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "[463, 455, 447, 439]" of type <class 'list'> for key "eval/totals" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "[21.598272138228943, 6.153846153846154, 3.131991051454139, 1.1389521640091116]" of type <class 'list'> for key "eval/precisions" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# 2022-02-14 11:13:56 [INFO] Tune 11 result is: [Accuracy (int8|fp32): 4.6663|8.0077, Duration (seconds) (int8|fp32): 28.6203|41.0515], Best tune result is: n/a
# 2022-02-14 11:13:56 [INFO] Save tuning history to /content/nc_workspace/2022-02-14_10-00-09/./history.snapshot.
# 2022-02-14 11:14:06 [INFO] |*******Mixed Precision Statistics*******|
# 2022-02-14 11:14:06 [INFO] +------------+---------+--------+--------+
# 2022-02-14 11:14:06 [INFO] |  Op Type   |  Total  |  INT8  |  FP32  |
# 2022-02-14 11:14:06 [INFO] +------------+---------+--------+--------+
# 2022-02-14 11:14:06 [INFO] |   Linear   |   133   |  132   |   1    |
# 2022-02-14 11:14:06 [INFO] +------------+---------+--------+--------+
# 2022-02-14 11:14:06 [INFO] Pass quantize model elapsed time: 9834.74 ms
# The following columns in the evaluation set  don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: highlights, id, article.
# ***** Running Evaluation *****
#   Num examples = 8
#   Batch size = 8
# Trainer is attempting to log a value of "[91, 26, 16, 10]" of type <class 'list'> for key "eval/counts" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "[438, 430, 422, 414]" of type <class 'list'> for key "eval/totals" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "[20.77625570776256, 6.046511627906977, 3.7914691943127963, 2.4154589371980677]" of type <class 'list'> for key "eval/precisions" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# 2022-02-14 11:14:35 [INFO] Tune 12 result is: [Accuracy (int8|fp32): 5.8240|8.0077, Duration (seconds) (int8|fp32): 29.1450|41.0515], Best tune result is: n/a
# 2022-02-14 11:14:35 [INFO] Save tuning history to /content/nc_workspace/2022-02-14_10-00-09/./history.snapshot.
# 2022-02-14 11:14:45 [INFO] |*******Mixed Precision Statistics*******|
# 2022-02-14 11:14:45 [INFO] +------------+---------+--------+--------+
# 2022-02-14 11:14:45 [INFO] |  Op Type   |  Total  |  INT8  |  FP32  |
# 2022-02-14 11:14:45 [INFO] +------------+---------+--------+--------+
# 2022-02-14 11:14:45 [INFO] |   Linear   |   133   |  132   |   1    |
# 2022-02-14 11:14:45 [INFO] +------------+---------+--------+--------+
# 2022-02-14 11:14:45 [INFO] Pass quantize model elapsed time: 9798.8 ms
# The following columns in the evaluation set  don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: highlights, id, article.
# ***** Running Evaluation *****
#   Num examples = 8
#   Batch size = 8
# Trainer is attempting to log a value of "[87, 25, 14, 5]" of type <class 'list'> for key "eval/counts" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "[459, 451, 443, 435]" of type <class 'list'> for key "eval/totals" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "[18.954248366013072, 5.5432372505543235, 3.160270880361174, 1.1494252873563218]" of type <class 'list'> for key "eval/precisions" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# 2022-02-14 11:15:15 [INFO] Tune 13 result is: [Accuracy (int8|fp32): 4.4200|8.0077, Duration (seconds) (int8|fp32): 30.3352|41.0515], Best tune result is: n/a
# 2022-02-14 11:15:15 [INFO] Save tuning history to /content/nc_workspace/2022-02-14_10-00-09/./history.snapshot.
# 2022-02-14 11:15:27 [INFO] |*******Mixed Precision Statistics*******|
# 2022-02-14 11:15:27 [INFO] +------------+---------+--------+--------+
# 2022-02-14 11:15:27 [INFO] |  Op Type   |  Total  |  INT8  |  FP32  |
# 2022-02-14 11:15:27 [INFO] +------------+---------+--------+--------+
# 2022-02-14 11:15:27 [INFO] |   Linear   |   133   |  132   |   1    |
# 2022-02-14 11:15:27 [INFO] +------------+---------+--------+--------+
# 2022-02-14 11:15:27 [INFO] Pass quantize model elapsed time: 11982.15 ms
# The following columns in the evaluation set  don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: highlights, id, article.
# ***** Running Evaluation *****
#   Num examples = 8
#   Batch size = 8
# Trainer is attempting to log a value of "[93, 34, 20, 12]" of type <class 'list'> for key "eval/counts" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "[455, 447, 439, 431]" of type <class 'list'> for key "eval/totals" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "[20.439560439560438, 7.6062639821029085, 4.555808656036446, 2.7842227378190256]" of type <class 'list'> for key "eval/precisions" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# 2022-02-14 11:15:57 [INFO] Tune 14 result is: [Accuracy (int8|fp32): 6.6639|8.0077, Duration (seconds) (int8|fp32): 29.7472|41.0515], Best tune result is: n/a
# 2022-02-14 11:15:57 [INFO] Save tuning history to /content/nc_workspace/2022-02-14_10-00-09/./history.snapshot.
# 2022-02-14 11:16:07 [INFO] |*******Mixed Precision Statistics*******|
# 2022-02-14 11:16:07 [INFO] +------------+---------+--------+--------+
# 2022-02-14 11:16:07 [INFO] |  Op Type   |  Total  |  INT8  |  FP32  |
# 2022-02-14 11:16:07 [INFO] +------------+---------+--------+--------+
# 2022-02-14 11:16:07 [INFO] |   Linear   |   133   |  132   |   1    |
# 2022-02-14 11:16:07 [INFO] +------------+---------+--------+--------+
# 2022-02-14 11:16:07 [INFO] Pass quantize model elapsed time: 9900.13 ms
# The following columns in the evaluation set  don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: highlights, id, article.
# ***** Running Evaluation *****
#   Num examples = 8
#   Batch size = 8
# Trainer is attempting to log a value of "[93, 24, 14, 8]" of type <class 'list'> for key "eval/counts" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "[460, 452, 444, 436]" of type <class 'list'> for key "eval/totals" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "[20.217391304347824, 5.3097345132743365, 3.1531531531531534, 1.834862385321101]" of type <class 'list'> for key "eval/precisions" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# 2022-02-14 11:16:35 [INFO] Tune 15 result is: [Accuracy (int8|fp32): 4.9921|8.0077, Duration (seconds) (int8|fp32): 28.8398|41.0515], Best tune result is: n/a
# 2022-02-14 11:16:36 [INFO] Save tuning history to /content/nc_workspace/2022-02-14_10-00-09/./history.snapshot.
# 2022-02-14 11:16:45 [INFO] |*******Mixed Precision Statistics*******|
# 2022-02-14 11:16:45 [INFO] +------------+---------+--------+--------+
# 2022-02-14 11:16:45 [INFO] |  Op Type   |  Total  |  INT8  |  FP32  |
# 2022-02-14 11:16:45 [INFO] +------------+---------+--------+--------+
# 2022-02-14 11:16:45 [INFO] |   Linear   |   133   |  132   |   1    |
# 2022-02-14 11:16:45 [INFO] +------------+---------+--------+--------+
# 2022-02-14 11:16:45 [INFO] Pass quantize model elapsed time: 9832.14 ms
# The following columns in the evaluation set  don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: highlights, id, article.
# ***** Running Evaluation *****
#   Num examples = 8
#   Batch size = 8
# Trainer is attempting to log a value of "[92, 29, 19, 11]" of type <class 'list'> for key "eval/counts" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "[461, 453, 445, 437]" of type <class 'list'> for key "eval/totals" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "[19.95661605206074, 6.401766004415011, 4.269662921348314, 2.517162471395881]" of type <class 'list'> for key "eval/precisions" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# 2022-02-14 11:17:13 [INFO] Tune 16 result is: [Accuracy (int8|fp32): 6.0873|8.0077, Duration (seconds) (int8|fp32): 27.9256|41.0515], Best tune result is: n/a
# 2022-02-14 11:17:13 [INFO] Save tuning history to /content/nc_workspace/2022-02-14_10-00-09/./history.snapshot.
# 2022-02-14 11:17:23 [INFO] |*******Mixed Precision Statistics*******|
# 2022-02-14 11:17:23 [INFO] +------------+---------+--------+--------+
# 2022-02-14 11:17:23 [INFO] |  Op Type   |  Total  |  INT8  |  FP32  |
# 2022-02-14 11:17:23 [INFO] +------------+---------+--------+--------+
# 2022-02-14 11:17:23 [INFO] |   Linear   |   133   |  132   |   1    |
# 2022-02-14 11:17:23 [INFO] +------------+---------+--------+--------+
# 2022-02-14 11:17:23 [INFO] Pass quantize model elapsed time: 9892.96 ms
# The following columns in the evaluation set  don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: highlights, id, article.
# ***** Running Evaluation *****
#   Num examples = 8
#   Batch size = 8
# Trainer is attempting to log a value of "[97, 30, 16, 9]" of type <class 'list'> for key "eval/counts" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "[479, 471, 463, 455]" of type <class 'list'> for key "eval/totals" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "[20.25052192066806, 6.369426751592357, 3.4557235421166306, 1.978021978021978]" of type <class 'list'> for key "eval/precisions" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# 2022-02-14 11:17:53 [INFO] Tune 17 result is: [Accuracy (int8|fp32): 5.4491|8.0077, Duration (seconds) (int8|fp32): 30.2000|41.0515], Best tune result is: n/a
# 2022-02-14 11:17:53 [INFO] Save tuning history to /content/nc_workspace/2022-02-14_10-00-09/./history.snapshot.
# 2022-02-14 11:18:03 [INFO] |*******Mixed Precision Statistics*******|
# 2022-02-14 11:18:03 [INFO] +------------+---------+--------+--------+
# 2022-02-14 11:18:03 [INFO] |  Op Type   |  Total  |  INT8  |  FP32  |
# 2022-02-14 11:18:03 [INFO] +------------+---------+--------+--------+
# 2022-02-14 11:18:03 [INFO] |   Linear   |   133   |  132   |   1    |
# 2022-02-14 11:18:03 [INFO] +------------+---------+--------+--------+
# 2022-02-14 11:18:03 [INFO] Pass quantize model elapsed time: 9678.9 ms
# The following columns in the evaluation set  don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: highlights, id, article.
# ***** Running Evaluation *****
#   Num examples = 8
#   Batch size = 8
# Trainer is attempting to log a value of "[91, 29, 18, 10]" of type <class 'list'> for key "eval/counts" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "[448, 440, 432, 424]" of type <class 'list'> for key "eval/totals" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "[20.3125, 6.590909090909091, 4.166666666666667, 2.358490566037736]" of type <class 'list'> for key "eval/precisions" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# 2022-02-14 11:18:31 [INFO] Tune 18 result is: [Accuracy (int8|fp32): 6.0226|8.0077, Duration (seconds) (int8|fp32): 27.3550|41.0515], Best tune result is: n/a
# 2022-02-14 11:18:31 [INFO] Save tuning history to /content/nc_workspace/2022-02-14_10-00-09/./history.snapshot.
# 2022-02-14 11:18:41 [INFO] |*******Mixed Precision Statistics*******|
# 2022-02-14 11:18:41 [INFO] +------------+---------+--------+--------+
# 2022-02-14 11:18:41 [INFO] |  Op Type   |  Total  |  INT8  |  FP32  |
# 2022-02-14 11:18:41 [INFO] +------------+---------+--------+--------+
# 2022-02-14 11:18:41 [INFO] |   Linear   |   133   |  132   |   1    |
# 2022-02-14 11:18:41 [INFO] +------------+---------+--------+--------+
# 2022-02-14 11:18:41 [INFO] Pass quantize model elapsed time: 9850.53 ms
# The following columns in the evaluation set  don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: highlights, id, article.
# ***** Running Evaluation *****
#   Num examples = 8
#   Batch size = 8
# Trainer is attempting to log a value of "[101, 41, 27, 17]" of type <class 'list'> for key "eval/counts" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "[465, 457, 449, 441]" of type <class 'list'> for key "eval/totals" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "[21.72043010752688, 8.971553610503282, 6.013363028953229, 3.854875283446712]" of type <class 'list'> for key "eval/precisions" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# 2022-02-14 11:19:10 [INFO] Tune 19 result is: [Accuracy (int8|fp32): 8.1982|8.0077, Duration (seconds) (int8|fp32): 29.1826|41.0515], Best tune result is: [Accuracy: 8.1982, Duration (seconds): 29.1826]
# 2022-02-14 11:19:10 [INFO] Save tuning history to /content/nc_workspace/2022-02-14_10-00-09/./history.snapshot.
# 2022-02-14 11:19:10 [INFO] Specified timeout or max trials is reached! Found a quantized model which meet accuracy goal. Exit.
# 2022-02-14 11:19:10 [INFO] Save deploy yaml to /content/nc_workspace/2022-02-14_10-00-09/deploy.yaml

# %% [markdown]
# Let's evaluate the time it takes to evaluate

# %%
start_time = time.time()
metric_quantized = take_eval_steps(q_model.model, trainer, metric_name)
elapsed_time = time.time() - start_time
print(f"Quantized model obtained with {metric_name} of {metric_quantized}, time elapsed: {elapsed_time}")
# Out:
# The following columns in the evaluation set  don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: highlights, id, article.
# ***** Running Evaluation *****
#   Num examples = 8
#   Batch size = 8
#     <div>
#
#       <progress value='21' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1/1 12:57]
#     </div>
# Trainer is attempting to log a value of "[101, 41, 27, 17]" of type <class 'list'> for key "eval/counts" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "[465, 457, 449, 441]" of type <class 'list'> for key "eval/totals" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "[21.72043010752688, 8.971553610503282, 6.013363028953229, 3.854875283446712]" of type <class 'list'> for key "eval/precisions" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Quantized model obtained with eval_score of 8.198151847957936, time elapsed: 28.835773706436157

# %% [markdown]
# How is the performance of this quantized model if we evaluate it on a larger sample size?

# %%
max_eval_samples = 100
eval_dataset = dataset.map(preprocess_function, batched=True)
eval_dataset_large = eval_dataset.select(range(max_eval_samples))

trainer = Seq2SeqTrainer(
            model=q_model.model,
            args=training_args,
            eval_dataset=eval_dataset_large,
            compute_metrics=compute_metrics,
            tokenizer=tokenizer,
            data_collator=data_collator,
        )

start_time = time.time()
metric_quantized = take_eval_steps(q_model.model, trainer, metric_name)
elapsed_time = time.time() - start_time
print(f"Quantized model obtained with {metric_name} of {metric_quantized}, time elapsed: {elapsed_time}")
# Out:
#   0%|          | 0/1 [00:00<?, ?ba/s]
# The following columns in the evaluation set  don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: highlights, id, article.
# ***** Running Evaluation *****
#   Num examples = 100
#   Batch size = 8
#     <div>
#
#       <progress value='3' max='13' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 3/13 00:57 < 04:49, 0.03 it/s]
#     </div>

# %% [markdown]
# ### Non-quantized version

# %% [markdown]
# For the non-quantized version, we have the following:

# %%
model = AutoModelForSeq2SeqLM.from_pretrained("sshleifer/distilbart-cnn-12-6")
tokenizer = AutoTokenizer.from_pretrained("sshleifer/distilbart-cnn-12-6")

# %%
trainer = Seq2SeqTrainer(
            model=model,
            args=training_args,
            eval_dataset=eval_dataset_large,
            compute_metrics=compute_metrics,
            tokenizer=tokenizer,
            data_collator=data_collator,
        )

# %%
start_time = time.time()
metric_std = take_eval_steps(model, trainer, metric_name)
elapsed_time = time.time() - start_time
print(f"Non-quantized model obtained with {metric_name} of {metric_std}, time elapsed: {elapsed_time}")
# Out:
# The following columns in the evaluation set  don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: id, highlights, article.
# ***** Running Evaluation *****
#   Num examples = 100
#   Batch size = 8
#     <div>
#
#       <progress value='13' max='13' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [13/13 02:57]
#     </div>
# Non-quantized model obtained with eval_score of 8.269434672683811, time elapsed: 191.84312677383423

# %% [markdown]
# The time it takes the non-quantized model to make a summarization doubles the time it takes the quantized model. However, this comes at a loss of accuracy: the BLEU score of non-quantized model is 30% higher than that of the quantized model. It is clear that the evaluation dataset during the tuning phase is too small.

# %% [markdown]
# Metric|Lpot-quantization |Baseline
# -----|-----|-----
# *BLEU*|6.31|8.27
# *Inference time*|87.76|191.84

# %% [markdown]
# ## 4. Conclusion

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# Model quantization in itself is a powerful technique for putting transformer models into production.
#
# Furthermore, neural compressor quantization offers a strong and mature-feeling alternative to the more well-known ONNX quantization.
#
# Definitely a keeper!
